# %% [markdown]
# # LEAD UNIVERSITY
# ---
# * **INTELIGENCIA COMERCIAL**
# * **Maestría Profesional en Comercio y Mercados Internacionales**
# * Alexander Franck, Guillermo Naranjo
# * 17 de Noviembre, 2018
#
# ### TEMA 3-B Información cuantitativa
# 1. Extracción, transformación y almacenamiento datos
# 2. Otras técnicas y herramientas para el análisis de datos
# 3. Presentación de la información (informes, tablas dinámicas, gráficas)
#
# Modified from https://lazyprogrammer.me/ course.

# %% [markdown]
# **OBJETIVO:** El siguiente ejercicio busca demostrar tecnicas recientes para extracción y procesamiento de información no estructurada. Particularmente se busca que el estudiante dimensione las grandes etapas del proceso, los retos y principalmente las oportunidades.
#
# **ETAPAS DEL PROCESO:**
# 1. Preparación del proceso
# 2. Extracción de datos de internet *(AMAZON REVIEWS)*.
# 3. Limpieza y transformación de datos.
# 4. Almacenamiento de la información.
# 5. Entranamiento del modelo de clasificación usando regresión logística.
# 6. **Análisis de sentimiento** a partir de los comentarios y calificaciones de Amazon utilizando técnicas de APRENDIZAJE DE LENGUAGE NATURAL.

# %% [markdown]
# #### PASO1: PREPARACION DEL AMBIENTE Y CARGA DE LIBRERIAS REQUERIDAS

# %%
''' SE CARGAN LAS LIBRERIAS WEB '''
# FUTURE permite compatibilidad entre versiones de Python
from __future__ import print_function, division
from future.utils import iteritems
from builtins import range

#NATURAL LANGUAGE TOOLKIT provee herramientas para interpretar lenguage natural
import nltk
from nltk.stem import WordNetLemmatizer

#NUMPY es una librería optimizada para calculo de vectores entre otras cosas
import numpy as np
import pandas as pd

#SKLEARN es una libreria que ofrece herramientas para data mining y data analysis 
from sklearn.utils import shuffle
from sklearn.linear_model import LogisticRegression

#BEAUTIFUL SOUP permite webscrapping, una tecnica de extracción de información web.
from bs4 import BeautifulSoup
import urllib as ul

#SE IMPORTAN OTRAS LIBRERIAS UTILITARIAS
import re
import ssl
import pickle

# %%
''' SE DEFINEN ALGUNOS PARAMETROS GENERALES'''
have_reviews = True
page_count = 1
all_reviews = []
max_pages = 150
word_index_map = {}
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36'
hdr = {'User-Agent': user_agent}
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
np.seterr(divide='ignore', invalid='ignore')
pd.set_option('display.max_colwidth', 500)

# %%
''' SE CARGAN LOS STOPWORDS -PALABRAS A IGNORAR-'''
wordnet_lemmatizer = WordNetLemmatizer()
stopwords = set(w.rstrip() for w in open('stopwords.txt'))

# %%
def save_reviews(value, file='reviews.pk'):
    with open(file, 'wb') as f:
        pickle.dump(value, f)
    
def load_reviews(file='reviews.pk'):
    with open(file, 'rb') as f:
        return(pickle.load(f))

# %% [markdown]
# #### PASO2: SE EXTRAEN LOS COMENTARIOS DEL SIGUIENTE PRODUCTO DE AMAZON
# *IMPORTANTE:* Los comentarios vienen paginados

# %%
url = 'https://www.amazon.com/Peets-Coffee-Aurora-Coffees-Flavors/product-reviews/B018NZJ4KK?pageNumber='

# %%
''' SE DESCARGAN LOS CONTENIDOS DE UNA PAGINA WEB DE REVIEWS '''
def get_reviews(url):    
    req = ul.request.Request(url, headers=hdr)
    html = ul.request.urlopen(req, context=ctx).read()
    soup = BeautifulSoup(html,'lxml')
    soup = soup.find('div',attrs={'id':'cm_cr-review_list'})

    #Encuentra los comentarios y los almacena en una lista
    comments = []
    for comment in soup.findAll('span',class_='a-size-base review-text'):
        comments.append(comment.text)

    #Encuentra las calificaciones y los almacena en una lista
    sentiment = []
    for rating in soup.findAll('span',class_='a-icon-alt'):    
        sentiment.append(1) if int(rating.text[0]) > 3 else sentiment.append(0)
    
    #unifica los comentarios y calificaciones
    l = [comments]+[sentiment]
    return(list(map(list, zip(*l))))

# %%
''' SE DESCARGAN TODOS LOS REVIEWS POR PAGINA '''
while (have_reviews and page_count <= max_pages):    
    print('Extracting comments from review page:',page_count)
    reviews = get_reviews(url + str(page_count))    
    if len(reviews) == 0:
        have_reviews = False            
    else:
        all_reviews += reviews
        page_count += 1

save_reviews(all_reviews)
# Out:
# Extracting comments from review page: 1
# Extracting comments from review page: 2
# Extracting comments from review page: 3
# Extracting comments from review page: 4
# Extracting comments from review page: 5
# Extracting comments from review page: 6
# Extracting comments from review page: 7
# Extracting comments from review page: 8
# Extracting comments from review page: 9
# Extracting comments from review page: 10
# Extracting comments from review page: 11
# Extracting comments from review page: 12
# Extracting comments from review page: 13
# Extracting comments from review page: 14
# Extracting comments from review page: 15
# Extracting comments from review page: 16
# Extracting comments from review page: 17
# Extracting comments from review page: 18
# Extracting comments from review page: 19
# Extracting comments from review page: 20
# Extracting comments from review page: 21
# Extracting comments from review page: 22
# Extracting comments from review page: 23
# Extracting comments from review page: 24
# Extracting comments from review page: 25
# Extracting comments from review page: 26
# Extracting comments from review page: 27
# Extracting comments from review page: 28
# Extracting comments from review page: 29
# Extracting comments from review page: 30
# Extracting comments from review page: 31
# Extracting comments from review page: 32
# Extracting comments from review page: 33
# Extracting comments from review page: 34
# Extracting comments from review page: 35
# Extracting comments from review page: 36
# Extracting comments from review page: 37
# Extracting comments from review page: 38
# Extracting comments from review page: 39
# Extracting comments from review page: 40
# Extracting comments from review page: 41
# Extracting comments from review page: 42
# Extracting comments from review page: 43
# Extracting comments from review page: 44
# Extracting comments from review page: 45
# Extracting comments from review page: 46
# Extracting comments from review page: 47
# Extracting comments from review page: 48
# Extracting comments from review page: 49
# Extracting comments from review page: 50
# Extracting comments from review page: 51
# Extracting comments from review page: 52
# Extracting comments from review page: 53
# Extracting comments from review page: 54
# Extracting comments from review page: 55
# Extracting comments from review page: 56
# Extracting comments from review page: 57
# Extracting comments from review page: 58
# Extracting comments from review page: 59
# Extracting comments from review page: 60
# Extracting comments from review page: 61
# Extracting comments from review page: 62
# Extracting comments from review page: 63
# Extracting comments from review page: 64
# Extracting comments from review page: 65
# Extracting comments from review page: 66
# Extracting comments from review page: 67
# Extracting comments from review page: 68
# Extracting comments from review page: 69
# Extracting comments from review page: 70
# Extracting comments from review page: 71
# Extracting comments from review page: 72
# Extracting comments from review page: 73
# Extracting comments from review page: 74
# Extracting comments from review page: 75
# Extracting comments from review page: 76
# Extracting comments from review page: 77
# Extracting comments from review page: 78
# Extracting comments from review page: 79
# Extracting comments from review page: 80
# Extracting comments from review page: 81
# Extracting comments from review page: 82
# Extracting comments from review page: 83
# Extracting comments from review page: 84
# Extracting comments from review page: 85
# Extracting comments from review page: 86
# Extracting comments from review page: 87
# Extracting comments from review page: 88
# Extracting comments from review page: 89
# Extracting comments from review page: 90
# Extracting comments from review page: 91
# Extracting comments from review page: 92
# Extracting comments from review page: 93
# Extracting comments from review page: 94
# Extracting comments from review page: 95
# Extracting comments from review page: 96
# Extracting comments from review page: 97
# Extracting comments from review page: 98
# Extracting comments from review page: 99
# Extracting comments from review page: 100
# Extracting comments from review page: 101
# Extracting comments from review page: 102
# Extracting comments from review page: 103
# Extracting comments from review page: 104
# Extracting comments from review page: 105
# Extracting comments from review page: 106
# Extracting comments from review page: 107
# Extracting comments from review page: 108
# Extracting comments from review page: 109
# Extracting comments from review page: 110
# Extracting comments from review page: 111
# Extracting comments from review page: 112
# Extracting comments from review page: 113
# Extracting comments from review page: 114
# Extracting comments from review page: 115
# Extracting comments from review page: 116
# Extracting comments from review page: 117
# Extracting comments from review page: 118
# Extracting comments from review page: 119
# Extracting comments from review page: 120
# Extracting comments from review page: 121
# Extracting comments from review page: 122
# Extracting comments from review page: 123
# Extracting comments from review page: 124
# Extracting comments from review page: 125
# Extracting comments from review page: 126
# Extracting comments from review page: 127
# Extracting comments from review page: 128
# Extracting comments from review page: 129
# Extracting comments from review page: 130
# Extracting comments from review page: 131
# Extracting comments from review page: 132
# Extracting comments from review page: 133
# Extracting comments from review page: 134
# Extracting comments from review page: 135
# Extracting comments from review page: 136

# %%
all_reviews
# Out:
# [['For years I roasted my own beans and the only reason I don\'t do it much lately is because I just don\'t ever have the time. So you end up too often roasting a batch of beans at 6 am so you can have a morning cup. Which means you\'re grinding and perking warm beans which is not optimal.So too much of a hassle and while I still do the occasional batch to my own particular taste, I have shopped around for a reliable substitute.The first thing I discovered is that you can pay a lot of money for some really mediocre to lousy beans. But I eventually managed tofind some primo stuff and this is one I highly recommend.I\'m not going to give you all that "floral notes and finish of absinthe" nonsense.  It\'s just good coffee, dark and rich and never bitter. These guys do a good job and you ought to give it a try. Maybe you\'ll like it and maybe it won\'t be exactly what you\'re looking for but either way you won\'t feel like you paid a premium price for a bag of mud,',
#   1],
#  ['After all these years, still the best coffee you can get.  Keep in mind that even the book about the history of Starbucks has a mention of how they wanted to model their product after Peet\'s... and Peet\'s just cares so much about flavor, roasting, complexity, etc., etc. that you can\'t go wrong.  You might say "welllllll, my local coffee house does an amazing job", but you know what, most local coffee roasters still don\'t have the expertise or the equipment, or the scientists and artists behind Peet\'s coffee... even Starbucks supposedly over-roasts their beans for consistency, and Starbucks is a little too speedy and anxiety causing for me.  Peet\'s is to Coffee what a great vintner is to wine... they\'re true connoisseurs.  Enjoy!  Also, as a suggestion, just keep shopping and shopping and shopping and eventually you\'ll see some great deals on here...',
#   1],
#  ["This is a good, strong coffee. It's not the original Major Dickason's Blend that put Peet's on the map in the late 1980's though. Back then the beans were quite rich and a real treat. As with any coffee bean over the years, crops change, so beans are not quite the same. I have found this to be true when ordering any of my favorites directly from Peet's over the past few years or via Amazon.I wouldn't call the newest incarnation of this blend bitter, but it is a tiny bit acidic. To balance the acidity, I usually put 2 scoops of Peet's French Roast in for a fuller body and smoothness. For me. that's the perfect cup as I love full-bodied, strong, but low acidity coffees that have a richness to them.I have read the reviews about receiving a stale bag after receiving one for the first time last week (use by date was only 6 days away and roast date was in the Fall of 2017). I would advise anyone going through Prime to just chat with them about this instead of negative comments. They have wonderful customer service reps who will take care of the matter. It would be a shame if this is the first time you tried the Major Dickason's Blend and didn't enjoy a fresh, robust cup. While not my favorite Peet's blend due to the acidity of late, it's still really good compared to other bagged coffees. If you like a weaker cup, just reduce by one scoop. It doesn't get watery, just a bit less in your face.",
#   1],
#  ['At times, making a good espresso seems to be a fleeting event. I do find with Peet’s Major Dickason’s whole coffee beans, my results are more reliable and consistent.While I drink several other beans and constantly try others, Peet\'s Major Dickason\'s Whole Beans are my go to coffee several days a week.I am a dedicated espresso drinker, but it has taken me years to make a good espresso at home. Saying "good" however, is a matter of opinion. I have had good espressos at some cafes and restaurants, but most of the time, I am disappointed, and yet these places have loyal customers, who buy the same espresso and enjoy it. For me a good espresso is dependent on three things:1. The quality of the beans2. The equipment3. The techniqueStarting with a simple screw on cover espresso machine, I have upgraded a couple of times over twenty years. I started with the standard Krups electric spice and bean grinder and while the grind was not consistent, I did not know anything else. I still have that grinder, and now, I only use it for spices.For me, a burr grinder was a turning point, but I never thought I would own one. After reading a couple Kindle e-books and scouring the web, I became obsessed with improving my technique, and to my surprise, my wife gave me a Rancillio burr grinder. (Great wife!).Along the way, I discovered Peet’s Major Dickason’s whole beans and then found it on Amazon for a great price, with Prime Shipping. It has become a solid performer for me, and while I go through periods of success and failure with any beans, Peet’s Major Dickason\'s whole beans are consistent. They give me a smooth cup, when I make it right. I have used many other beans, and have a few other favorites, but Peet’s Major Dickason’s is my day-to-day go to coffee.I made the mistake of ordering the ground coffee (vs. whole beans) a month ago, and could not use it for espresso. I tried using it in my Moka Pot, but the grind was too coarse. I immediately ordered the whole beans, because the price is typically as good I can find it locally, and as a Prime member, I get the beans in two days. Why go to the store, when I can have them quickly delivered to my home?My other performers are Bella Finca (Henry’s House of Coffee, San Francisco) and one of Atomic Coffee Roasters espresso (Beverly, MA). Atomic has two different espresso beans, but I cannot recall the one I like better. Both are sold by GoCoffeeGo on Amazon. GoCoffeeGo has a $5 shipping charge, so those coffees are too expensive for my normal budget. I have enjoyed the Kicking Horse coffees on Amazon: Kick Ass, Grizzly Claw and their 454 Horse Power, in that order. I find, as mentioned by other reviewers, that Kick Ass beans are inconsistent, which is very disappointing. Recently it doesn’t even taste like the same coffee I have had from them for the past eight months, otherwise, I would drink more of it.As to technique, my preference is to keep my beans in a steel vacuumed coffee canister on the counter, measuring out 15.6 grahams of beans, a fine ground (it’s all relative, I grind it to get my targeted pour time and taste), a firm five-point tamping method, preheated cup and saucer, and 25 +/- second pour. I strive for a dark honey colored stream, with plenty of crèma, which I read is the “Holy Grail” of the espresso world. The delectable brew is captured in a little measuring marked shot glass. I do a lot of praying during these moments, I talk nicely to all my equipment and cheer them on. When everything lines up, the result is a perfect cup for me. There are days where I must walk away from my attempts. At times, making a good espresso seems to be a fleeting event. I do find with Peet’s Major Dickason’s whole coffee beans, my results are more reliable and in my world, a good smooth doppio (2 ounces) with a nice crèma, is a wonderful thing.',
#   1],
#  ["Disappointed. Received the package 12/20 that was roasted 9/18 and best by 12/17 so past the best by date. Usually when ordering via Amazon things are much fresher. I won't be ordering this product again. Which is a shame because it is quite good. Usually you get a discount for out of date products not a full price tag.",
#   0],
#  ["This is a review for the addon listing of Peet's Major Dickerson blend.I've been a Peet's convert for a while now, in fact Peet's ruined my preference for medium roasts with it's Maj D blend and I was quite a coffee snob willing to spend more for quality at other website roasters typically ordering around 7 lbs a month.  But when I discovered Maj D I was surprised at how rich, complex and satisfying of a roast it was.  For a while I ordered from their website but I'd check in with amazon from time to time and saw they had this listing while shopping one day.  Gave it a shot as I'm always a bit cautious about ordering whole beans off of Amazon when its Prime but knowing what the roast to order tasted like I had a good foundation for comparison.  I can happily say its the same and at the price listing (I have no trouble hitting that $25 minimum) its a solid win.  I often shop around trying other roasters/blends, but Peet's is my roaster of choice, they really are for my tastes, the best.",
#   1],
#  ['I don\'t have enough time to write as many reviews as I did years ago, and via my participation with Amazon\'s Vine Voice program I get free items in exchange for my unbiased review so it is EXTREMELY infrequently that I write a review just for the reason of "this product is absolutely the best."I don\'t remember the first time I got to experience Peet\'s Major Dickason, but it was years ago and, ever since, as far as I\'m concerned, there\'s not really a use for any other coffee.The sense of smell is one most closely tied to a strong emotional reaction. Think about the smell of frying bacon, or the smell of a really fine bakery, or a fragrant, blooming rose. Major Dickason\'s is that kind of smell - it\'s not just a *good smell.* No, it\'s a smell that\'s so good it conjures up in my head the best feelings and emotions. If you haven\'t had the pleasure you may be wondering "well.... what does it smell like?"Coffee. It smells like coffee - but it smells like the best coffee imaginable: like God gave you a nose for no reason other than to smell Major Dickason\'s.It\'s worth mentioning that it tastes as good as it smells. I constantly have Major Dickason\'s k-cups around for when I\'m pressed for time and I just HAVE to have a cup of coffee. I also constantly have whole beans, which I grind fresh and brew either in the keurig or the ninja - but the truth is Major Dickason\'s will turn a cheap 10 dollar coffee pot into a barista-inspired heaven that the most expensive coffee-brewing equipment, without Major Dickason\'s, can\'t hope to duplicate.Peet\'s Major Dickason\'s is one of the ways I know God loves us.',
#   1],
#  ['This is the only coffee that should exist. Major Dickason’s Blend is so dark that it sponsors Kylo Ren and The First Order.If you like your coffee to taste like coffee should, buy a couple bags of this every month and buckle up.',
#   1],
#  ["I've found Peet's coffee to be the finest & tastiest available at (nearly) any price.  The quality, consistency & flavor are well above average.  This Dickason's Decaf may be the finest cup of unleaded Joe you'll ever have.  I've searched for many years to find the perfect cup (of decaf) and this might just be it.Nothing from Folgers, Gevalia, Seattle's Best, Community, J&B, Starbucks or otherwise, even comes close.  Smooth, ripe coffee flavor with a deeply satisfying dark(ish) roast.  Well rounded & full flavor profile with scarcely any acid.  Has enough character and fortitude to substitute well for espresso, when pressed.  It's seriously satisfying, no-compromise Decaf... and I never thought I'd say that.  Cheers!",
#   1],
#  ["UPDATED April 2018: Peet's stop making the decaf house blend over 6 months ago. On February I saw it back here and  I purchased 4 of them thinking that after it was discontinue they brought it back, big mistake, this is nothing like the old decaf house blend, it is bitter and the flavor is very bad. I wasted my money buying these. Not sure why they even call it the same if it is different coffee taste. I trashed all of them.By far one of the best decaf coffees out there. It is better if you purchase it fresh from their store. This one you'll need to grind a little more if using for espresso which I do. My friends can't tell is decaf, I have one friend that always tell me no decaf for me, I only drink real coffee and can tell,  I will  not drink decaf, well, she had been drinking this one every time she comes over and doesn't know. Very sneaky of me but it tells you how much it taste like the real thing. LOL",
#   0],
#  ['My favorite decaf coffee and it’s water processed, which is amazing. The first water processed where I don’t notice the coffee tasting “off”If you’ve tried other water processed decaf coffee and thought it tastes different I urge you to try this one. I purchased a few popular water processed decaf coffee’s and didn’t like the taste- I didn’t even realize this was water processed until reading the bag. Love that it’s healthier then the other decaf blends.',
#   1],
#  ["Peet's Major Dickason's coffee is hands down my favorite coffee. I used to love French Roast but find Major Dickason's to be a superior blend. It's got a deep, rich, robust flavor that's smooth, complex and satisfying. I also find it to be less acidic than your standard coffee.I use an Aeropress coffee maker (available via Amazon) using 3 Tbsp of freshly ground beans (roughly 15 grams) with 12 ozs of 205°F water for each mug of coffee.The price on Amazon is excellent for this whole bean coffee. I use Subscribe and Save to get this monthly staple and the beans are always taste freshly roasted.",
#   1],
#  ["I am not kidding.  I am a coffee nut (aficionado).  I love coffee and have been through the gambit of coffees and this is the best grind I have found short of the $40 a pound gourmet beans.I  have not seen this particular roast before, but it is dark and rich with oils soaking the beans.  When it grinds, the aroma is phenomenal for this grade of coffee.  I have now made regular coffee with it in a french press, espresso and even filled a refillable keurig filter with it, and every cup came out great.  The espresso has a wowza kick to it!!  I have had my espresso machine for a while, and I don't remember getting a kick like this from a cup of espresso in a very long time.The flavor of each is at the very high end of anything you could likely get for under $30 a pound.  It beats out Starbucks Sumatra easily.  It trumps many other brands I have tried, even the allegedly organic beans from Whole Foods.  What is amazing is the after taste.  It lingers, probably because of the oils in the coffee, and the flavor is fresh on the tongue even a few moments after you finish the cup.If you are a cream and sugar person, do not bother with this.  It is not for you.  You will never appreciate the difference.",
#   1],
#  ['I have tried literally dozens of coffees out there. I always thought i was a dark coffee person and had a hard time finding a good coffee to fit my palette. This coffee had a very nice rich, velvety and smooth flavor. No acidy bite at all. I cannot find it in any local stores in my area so amazon keep this coffee!!This is my daily coffee now. Great price too!! Try some for yourself!!! A++',
#   1],
#  ["Made my usual cold brew with my Toddy, and was recommended to try this by a friend. Typically I'll spend a few extra dollars for some of my favorite dark roast coffee beans, but wanted to see if I could save some money while still having a great cold brew. Unfortunately, I found this to be unusually bitter and strong with my regular 12 hour process. Perhaps this is best left as a hot brewed coffee, as there's just no body or discernible flavor notes to it.",
#   0],
#  ['Over the last 40 plus years, I have made do with  some of the worst coffee imaginable in the military , had some good coffee, but have always been searching for a GREAT coffee.  I\'ve tried everything I could lay my hands on, except for the coffee eaten and then "recycled" from the Civet cat. (who thought of that??) I found Starbucks coffee to always have a sort of burned taste, Gevalia to have no "edge" at all, etc, etc. Finally, I found Peet\'s Maj. Dickenson. Not bitter, but not bland. I\'ve been drinking it for about 5 years now, and still stop to savor that first sip of the day. Great body, perfect flavor, what more can you say?',
#   1],
#  ["This coffee has become my hands-down favorite coffee! I used to only drink dark roasts, then found my way to lighter roasts. I would say this is pretty similar to Starbucks Veranda, but totally better. I used to buy Starbucks Veranda, but have been drinking the Colombia Luminosa for a few months now and completely love it. It seems to have a brighter, more complex flavor. Peet's Big Bang is great too, but this is my favorite. I'm pretty disappointed that they are out of stock right now, so my recurring monthly order isn't being shipped. I'm drinking the Big Bang roast that I picked up at my local Kroger, but they were out of Colombia Luminosa too. Bring it back!",
#   1],
#  ['Taking into account its decaf bar none it\'s the "Best dang coffee I\'ve ever had".\xa0Peet\'s Coffee, Decaf French Roast, Dark Roast, Ground Coffee, 12 oz. Bag, Decaffeinated Coffee, Bold, Intense & Complex Dark Roast Blend of Latin American Coffees, with a Smoky Flavor & Bite\xa0Decided to get off the caffeine and woe was me. After the week long headache I tried and tried to find a good bold reasonably priced  DECAF coffee. FYI, you  won\'t find one in your local grocery store. I even went old school and started using a percolator on the stove top. After going through at least Seven (7) brands failing to make the grade I gave Peet\'s a try. This coffee is so good I cut out using sugar which is great as I inch closer and closer to diabetes as I age (runs in fam). Long story short, if you want a Great Decaf that won\'t break the bank this is it!!!',
#   1],
#  ["Peet's decaf coffees are among the best I've had in decaf. The flavors are rich, complex and balanced, with no strange aftertastes like I get with some decaf coffees. I've tried the decaf versions of French Roast, Major Dickason's Blend and House Blend. French Roast is the darkest and most robust of the three, a truly traditional and satisfying French roast style. Major Dickason's is dark-to-medium with superb combination of of bright and deep aromas, and makes an excellent brew, even at varying strengths. House Blend is a medium roast, the lightest of the three, and makes a delightfully smooth cup. All three are highly recommended!",
#   1],
#  ["I've tried so many different brands of coffee. This coffee is one of the best ones I have tried. It is bold and very good tasting coffee. A bit strong too. I do not need as much grind as I used on other brands when making coffee. This is great!",
#   1],
#  ["Delivered 10/5/17.  Product 'best purchased by' 10/11/17.  Not the first time this has happened; be careful when purchasing.  Always check dates before opening.",
#   0],
#  ['I used to work at Peets in college. For me there is no better coffee out there. My espresso always comes out beautifully with a perfect crema. Any coffee from Peets will always be bold but not bitter. I don’t know how they perfectly roast it (I should considering they put me through my senior year of college) but it is magical. Major Dickenson or Mocha Java is my choice of brewing coffee, too.',
#   1],
#  ['I thought among the more experienced connoisseur reviews, there might also be some people out there like me who would benefit from a less refined but still specific perspective. E.g. Only a few years into making your own grinds, not a particularly experienced palate, and with some health needs when it comes to purchasing coffee.I\'m a weird duck. Everyone from doctors to researchers to popular coffee websites all seem to advocate that darker roasts are the way to go if you\'re an acid sufferer. But dark roasts have always, always made me sick. For days after drinking them - regardless of brand - I have horrible acid. For that reason, I\'ve also come to personally dislike the intense smokiness that many darker roasts have. Lighter roasts, for whatever reason, contrary to the prevailing wisdom, don\'t affect me in the slightest. Maybe I have weird gut pH? Go figure lol. But I\'m very pleased to say this coffee doesn\'t affect my stomach at all.I\'ve been searching for a coffee, starting with medium roasts (and will soon work my way up towards very light roasts, and see how that goes) that is flavorful and aromatic in a way that isn\'t smoky or "roasty," but that is palpable and which doesn\'t hurt my stomach. And so far, this blend is a pretty good match for what I\'m looking for.It\'s very mellow. It\'s also, despite my lack of experience, what I would say I think of when I envision a "true" medium roast. None of the beans are over-roasted. So many "medium" roasts can smell and taste like dark roasts to me, sometimes being even darker and "roastier" than other roasts labeled as dark! Not so here. Very, very mild, unless you extract for longer than 4 minutes. (I use a french press.) And even then, up to 6 minutes (yes I know you\'re not supposed to extract longer than 4 - I\'m just explaining how mild it is), it only becomes very moderately more "roasty."And darned if it doesn\'t faintly smell of blueberries as claimed, due to the Ethiopian Super Natural inclusion in this blend. It\'s not as present as a blend centered completely around that hint, but it\'s there, faintly but pleasingly. At 4 minutes extraction, with non-boiled but just beginning to steam water (yes I know I should be more precise thermally) it tastes like what most people would probably call "normal coffee." Mellow, mild, but with that great blueberry, earthy aroma. At 5 minutes it\'s definitely stronger and more flavorful, but still very mild. At 6 minutes, it\'s JUST beginning to taste "roasty" and a little more smoky, but still not very better imo.If you love really dark roasted tasting coffee, this is not the blend for you. But if you just want a nice, smooth, mellow coffee, that also has decent body and a pleasing aroma (especially at longer extractions,) you might really enjoy this. The aftertaste is very mildly citrus, and doesn\'t "tingle" as much as other blends I\'ve tried. I\'m going to try some others, as I said moving up the roast lightness scale, but if none of them sit well with me, I could easily drink this as my daily coffee. No real downsides, not the most flavorful ever but definitely has presence and smells wonderful - although the aroma is as gentle and mellow as the flavor. I guess this is what people call "balanced" in the coffee world. If it is, I like it.Oh, and it has a bit less caffeine kick than some others I\'ve tried. Which is either a good thing or not depending on what you want lol. Keep that in mind. Hope this helps someone out there with needs similar to mine.',
#   1],
#  ["'Cook's Illustrated' rated this coffee the best of medium roast coffees.  I am a coffee lover, and I love medium roast coffee. I could not find this coffee at my local supermarket, but did find it at Amazon. This is an expensive coffee at Amazon, $37.50 for two 12 -ounce bags. The supermarket charges $13.95 for a 1-pound bag.I like dark French Roast coffee, and I wanted a break. I found this coffee to be extremely smooth and bold. It is rich and with a chocolate toast flavor. This is what coffee should taste like. The beans seemed fresh and when ground had a remarkable odor. Peets is a coffee of renown, and is well known in the Northwest. It's gaining a foothold in the Northeast. My daughter in Seattle purchases only Peets, and when there is a sale, I buy in bulk. The smooth full-bodied taste of Peet's is what this brand is known for.  The Cafe Domingo coffee is one of the best coffees we can buy.Highly Recommended. prisrob 03-20-13",
#   1],
#  ["Coffee beans are obviously old. No aroma, absolutely no flavor. I'm stuck with 3 more bags which are of no use to me.",
#   0],
#  ["I've heard good things about this brand but the order I tit was sevverely burnt beans. I tossed them Into the trash.",
#   0],
#  ['I love this coffee! I go through about 4 bags a month (thank you amazon subscribe and save) and I enjoy it very much. It is good hot or iced. This is not a coffee with a bitter after taste and it has a very smooth and rich taste. I don\'t really taste any "mocha" in this, but it\'s still my go to coffee. I found it originally at a Whole Foods in CA and I was paying nearly $12 per bag, but luckily, I found it on here and can usually get it for around $5 a bag with subscribe and save. I gave some to my friend to try and she loved it as well. I would highly recommend this coffee to anyone that loves a decaf dark roast coffee.',
#   1],
#  ["Try it for Peet's sake! I discovered this blend while on vacation last year. I had heard of Peet's but never tried it. Fast forward a year, and now I have tried a couple other blends from Peet's. In my opinion, the House Blend is the best. It is better than the Major Dickason Blend, which is much easier to find in stores for some reason. The House Blend just has the right balance for my tastes.",
#   1],
#  ["I elected to kick caffeine a few months ago, but still enjoy coffee.  It's hard to find dark roast decaf, so I was very happy to see this at Amazon.  Tastes pretty good, usually doesn't keep me awake. Way better than any of the alternatives I've found in local grocery stores.  I keep waiting for the price to shoot up, but so far it's remained a pretty good deal.The bags normally arrive in a non-vacume state (bag is floppy rather than rigid), but the grounds taste fresh enough for me.  The grind is about right for my drip coffee maker.",
#   1],
#  ["While I like this coffee, this is the fourth time getting coffee that is out of date. I usually order 4 bags at a time. Also the huge fluctuation in price is really annoying and off putting. I have started looking into other coffee so I don't have to deal with inconsistent pricing and dates.",
#   0],
#  ["I've been enjoying the espresso roast whole beans for use in my French press. The stores I frequent don't carry it, so I'm glad to find it here. Like all Peet's I've tried, the coffee has a great, full flavor. The espresso roast is just a great dark roast, plain and simple. So far, I haven't had issues with freshness or quality. My coffee only turns out bad when I occasionally burn it with too-hot water, or other factors. I also have a sensitive stomach and this doesn't seem to be overly acidic. Pairs well with So Delicious non-dairy creamer. I use a Hario burr grinder and nothing else fancy, so I can't report on espresso machine uses or anything. It's just d-mn good coffee, the kind of thing agent Dale Cooper would like.UPDATE 4/12/18: I've been grinding the espresso beans and making fantastic cold brew. Thought about trying other coffees for funsies, but this is tried and true. (I use a hemp filter bag and 60 oz Takeya pitcher.) The flavor holds up with the beans frozen until grinding.",
#   1],
#  ["This coffee has changed--and not for the better. It's not the rich, smooth, delicious Major Dickason's I've been making for years. It's pretty flavorless and thin, even though I use the same coffee-water ratio as ever. The package itself is slightly but noticeably different from the traditional one, and there are no images of this new package on either Google or Peet's website. This tells me that this bland junk might not be the authentic Peet's offering. Now I have to find a new source for my morning Peet's fix.",
#   0],
#  ["Peet's major dickason blend is by far my favorite coffee. It is bold yet not too acidic and have a solid long-lasting flavor. I find it not too strong for my first cup in the morning yet gives me enough of a kick to get me going.The coffee always comes fresh, and the beans usually still have an oil on them. I definitely prefer the whole beans and grind them myself to get the most flavor out of them. The one downside is that they go stale after about 2 weeks of after opening the package.",
#   1],
#  ['I\'ve been hand grinding this, super finely, to make Turkish coffee.  It works very well for that.  The only problem is that this uses it up very slowly, and I\'m past the "best by" date, but it\'s still good for now.This roast is on the darker side of medium, and is not bad for making regular coffee with a different grind and a French press, although generally I prefer a dark roast for that.',
#   1],
#  ["Fresh Covfefe from Peets delivered to my door. It's great to have backstock of an essential like this. It's fresh in its sealed bag, just like from the Peets stores. The product dating is good. One comment though for price shoppers: There's a lot of variation in the coffee markets with bean prices, etc. Watching local grocery stores and stocking up on sales is probably the same or better than ordering online, which locks in a price that may change substantially with the season.",
#   1],
#  ["I really like Peet's House Blend and buy it when it is on sale at Amazon or my local grocer. It is rich and smooth and a great eye opener in the morning. It is now on my rotation of coffee's that I drink.",
#   1],
#  ["Peet's is best coffee I've had. I'm in my 60s. Get yourself a grinder and a French press and you will never drink Folger's or anything similar again. Comes in whole bean or ground. Worth every penny.",
#   1],
#  ["Great-tasting dark roast coffee. I remembered enjoying it years ago, when I had a french press and I thought dark roast was my favorite. Recently, I've been leaning more toward medium roast, but even more recently I acquired a french press and grinder, and it was time to buy beans again. I remembered Peet's and Major Dickason's, and wanted to try it again. I was concerned I wouldn't like it as much now, since I've been veering away from dark roasts, but it was just as I remembered. Great taste.",
#   1],
#  ["Can't believe how great this coffee is ... reminds me of Yeti Imperial Stout (IYKWIMAITYD)!!!  I've now put this on S&S, as I think it just might be my favorite.  With this in rotation with Kicking Horse Kick Ass and Ruta Maya Dark, you can't go wrong.  drf",
#   1],
#  ["My husband and I have tried a lot of brands of coffee. Peet's is by far our favorite. The dark blends are our go to. We use this 12 oz bag to fill our Keurig pods and it lasts us two weeks with about two 10 ounce cups a day. I'd describe it as a warm, smooth, smoky, nutty, rich flavor that will definitely wake you up. It's the Ghirardelli of coffee, in my personal opinion. Take that for what it's worth, Folger's is like dirty water to me and Dunkin' Donuts is so acidic that it turns my stomach.",
#   1],
#  ["We love this coffee and subscribe to receive it every month, so we don't have to worry that I will run out.  It is a nice, rich cup of coffee without being burnt or bitter. We typically make two 10-cup pots each morning just for the two of us. I take it with me when I travel with a single cup cone and filters so I am sure of a good cup wherever I am.",
#   1],
#  ["Can't beat Peets.  If you haven't tried Major Dickason's, you're missing out.  It's full bodied and dark, but I think it's the best selling of Peets Coffee.  One of my clients offered me Peets one day. They couldn't believe I hadn't had it. (This was years ago.) Anyway, it's a rich, incredible coffee. Costco in CA carries it, but here in NC they tried it and I guess it didn't sell too well.  It's the best, really.  You pay more for it, but it's worth it.",
#   1],
#  ["I love coffee and I subscribe to Mistobox which send me coffee every couple of weeks. But I love Peet's coffee because it's very cheap which means that I can drink tons of coffee and not go broke.Even though this coffee is less than ten bucks, it still tastes super good compared to other less expensive coffees.",
#   1],
#  ['I wanted to try darker roasted beans than what I usually get (Kimbo Superior - medium roast, excellent stuff, Italy). I was disappointed at first due to the bitterness but tasted some potential. I eventually dialed down my vintage Olympia Cremina lever espresso machine to pull shots at lower temperature. Results have been quite amazing. I am not good at describing flavors but it is only very slightly bitter if you use a lower temperature (if you machine allows for that) and tastes excellent, especially at the Amazon price. I recommend you try a bag.',
#   1],
#  ['This coffee turned out to be one of the better coffees I have tried. As I am new to the “grind then beans” scene, I have been trying different types. Pete’s Major Dickason blend was a pretty good coffee over all. However, with that being said, the price range to quality ratio is off. The price is a little high for a coffee that doesn’t completely blow me away. Like most coffee and other food products it’s all up to personal preference however.',
#   1],
#  ["Absolutely best dark roast decaf available! Rich, deep nutty flavor. Excellent for regular, bold, iced coffee and expressso. Brews the best cup of coffee I've ever made with my Ninja Coffee Bar IQ. Also does great with my Keurig 2.0 and Hamilton Beach 49981A Single Serve Scoop Coffee Maker. Tastes even better with sweetened Half & Half froth.I've found my new fav!",
#   1],
#  ["Very disappointed.  Ordered Feb 12, received Feb 14, Best Buy date Feb 26 (3 months after roast date).  I can't drink a 12oz bag of ground coffee in 12 days and 3 month old ground coffee is pretty stale anyway.  This was for ground decaf.  I ordered the most popular blend, Major Dickason, in hopes of avoiding this problem.  I also ordered Major Dickason whole beans.  Those were also 3 months after the roast date, but beans last longer than ground so I guess I'll keep them.  The ground will be returned.",
#   0],
#  ["My brother turned me on to this coffee last November (2017). I was drinking Kirkland's Brand decaf (roasted by Starbucks) beans that I ground myself and that was pretty good. However, this has to be one of the best grocery bought, pre-ground coffee I've had. It isn't bitter or acidic, is so smooth and full bodied. It really is the best thing I look forward to each morning. I wish I could find it in the stores around me though so I don't have to order it but I have yet to find a store that carries the decaf, and forget about trying to find the beans to grind yourself. So, I'll settle for this for now.",
#   1],
#  ['not sure if I got a bad gab.. tasted and smelled horrible.  Others seem to like so maybe i just got a bad bag.',
#   0],
#  ['Every one of the 5 bags expires in less than a month from the day I received it.  This is just unacceptable.',
#   0],
#  ["WOW. This light roast is FULL of flavor. Aromatic with vanilla and fruity notes. Light. Crisp. Flavorful. If the bag didn't say light roast I would not have believed it. I used the inverted AeroPress method. And for THAT PRICE! This is a steal! Peet's is hands down THE BEST coffee money can buy.",
#   1],
#  ["I have been using the Peet's Coffee Colombia for 5 years and I love it but this one taste very different/bad from the colombia I'm used to drink. I bought 4 packs here, the packs arrived sealed and looks in normal condition but something is wrong with the grain, it's taste awful, totally different of Colombia one.I opened three packages, I tried all them but it had taste the same.",
#   0],
#  ["Tasty every time I get it and I just mix with a little caffeinated coffee and I'm good to good. Lots of flavor, unlike most decaf coffees",
#   1],
#  ["If this isn't one of the best cups of coffee you ever had then I will be shocked. If it was legal for me to do it, I would almost give you your money back. The only coffee I think is better than this one is Trader Joe's Wintry Blend. You will love this and you'll be all jacked up on caffeine and super productive. Get it. Sip it. Hold it in your heart. Hug it because you know you want to. Coffee is God.",
#   1],
#  ["Everyone says they are a coffee snob.  Even the ones that love coffee I can't stand.  This stuff is one of the best all-around coffees which is great to drink hot or make a great cold-brew.  I wish it came in bulk options because the price has set me off to explore other options which, are widely available in a competitive coffee market.  When it's on sale, I buy it.",
#   1],
#  ['Bought 4 bags and all of them say best if purchased 3 months ago', 0],
#  ["Peet's Coffee Brazil Minas Naturais, Medium Roast, Ground 12oz -I wish they wouldn't mix different products in the same reviewsAt this price point I'd give it a 6 if I could.I have no problem paying 9 bucks for a 12oz bag of Peets French Roast,etc.But this price? I had to come back and check to see if I hadn't gotten over on a price mistake,but nope.I might have to demote the Major.",
#   1],
#  ["My coffee arrived with an expiration date of 12/31/17. It's part of a Christmas gift. I highly doubt they will use it in a week. Very disappointing...",
#   0],
#  ['Very god coffee. I used to drink Starbucks French Roast, but got a sort of sour flavor as the cup cooled. I even tried some French roast from a local coffee shop, but noticed the same problem as the coffee started to cool. Peets has a nice rich flavor that stays that way even when the coffee starts to cool. I like it so much I subscribed for regular deliveries.',
#   1],
#  ['It\'s quite bitter almost like an espresso; and I like that. It\'s espresso enough to make an iced-coffee with it. Does it taste good? Well... maybe a little deeper taste than Maxwell coffee. It\'s grinded, so don\'t expect the same quality from freshly grinded whole beans. Do I recommend it? Well, yeah actually if you like strong bitterness of coffee. Speaking of bitterness, does it taste "sour"? Actually no, and that\'s a big plus.',
#   1],
#  ['Great decaf coffee.  Still searching for my favorite, but this will be my go to for a while.  I like a bold cup of coffee in the morning and can’t drink much caffeine anymore.  Finding a good decaf - particularly one that is not processed with chemicals - is a challenge.  I’d recommend trying it!',
#   1],
#  ["As advertised, an excellent Dark Roast coffee intended for a thank you package to the coffee lover...I bought several brands to say thank you for a deed well done and will post this review in each. This one was to represent the Pacific Northwest's love affair with dark roasted whole bean coffees and how they blend different beans into specific flavor profiles....dj",
#   1],
#  ["I make coffee at night and it's ready when I get up, and it the greatest thing to wake up to.  I have to add it tasted good also.  I've tried all kinds of coffee and PEERS dark ground is the best I have found.  I grew up with the store brand and there ok, but  PEETS coffee. Is on the top shelf and I don't know if there is anything better.  In looking but haven't found one compared to PEERS dark roast coffee.",
#   1],
#  ['It smells good but found ground and thought I made mistaken. I could not return because 6 weeks after delivered it.I took two proven photos if seller contact me',
#   0],
#  ['I had been looking for a good tasting decaf coffee, due to "no sleep" issues and was certain that I would have to settle for ok coffee.  I was impressed by the reviews this one received so I gave it a try.  Let me tell you this is the BEST coffee ever, decaf or not.  I love it.  Thanks "Peet" for coming up with this blend.  I\'ll be a customer forever.',
#   1],
#  ['I have this as a subscribe and save item. The best by dates are usually very close to when I receive the coffee, however this month I received it on January 5th and the best by date had already passed-- January 1st. I will go back to buying from the supermarket if this happens again...Update- just received a bag dated 3/21/18. Today is 5/8/18. They are sending old coffee.',
#   0],
#  ["Major Dickenson's blend is a robust, dark raost coffee. It has a true sweet note to it, but without any strange flavors that can alter the true coffee flavor.In my Cuisinart extreme brew coffee maker I add 1 heading teaspoon of ground coffee for each cup of coffee I want to make. It turns out prefect every time.",
#   1],
#  ['Great coffee beans. Gave this as a gift to my husband for his new espresso machine from santa :-)He says it taste really good and the beans grind perfectly. Will forsure buy again when he needs more.',
#   1],
#  ["I love Pete's Big Bang coffee when buying it ground in the store. So I Thought Whole Bean Would Be better Because It Would Be fresher. This coffee has a slight fruity taste, which is really brought out by the fresh bean! I actually don't like it as well. But the product ordered was exactly as described!",
#   1],
#  ["I found this coffee too light and sweet for my personal tastes, but I appreciate that others will probably like it.  There's very little earthiness or smokiness, yet it has a heavier mouth feel.  It drinks fairly smooth, though the acidity is noticeable after a few sips.  There is a distinct caramel/toffee sweetness that lingers in the aftertaste.",
#   1],
#  ["I LOVE this coffee. It's flavorful without being overpowering. I highly recommend this. However, I placed my order on 12-23. The package said it was roasted on 9/28 and freshest by 12/17. If anyone appreciates fresh coffee, just be aware and see if you can find out about dates before purchasing.",
#   1],
#  ['I got teo packages of this coffee and the best purchased by date is in a week! The guaranteed fresh date is also only one week from today. It was a subscribe and save order but I am not buying this product again',
#   0],
#  ['Good taste for coffee and good price. I do not like acidic tasting coffee, and this coffee does not taste acidic while giving a good flavor. Whole bean so you can grind the beans yourself!',
#   1],
#  ['Good taste for coffee and good price. I do not like acidic tasting coffee, and this coffee does not taste acidic while giving a good flavor. Whole bean so you can grind the beans yourself!',
#   1],
#  ['This coffee is special.  You cannot tell it is a decaf coffee, so you get real, full bodied flavor without the caffeine jitters.  I make a big thermos and I drink it all day at work.  Of course, you still get some caffeine, but that’s not a bad thing.  This particular blend is their most popular.',
#   1],
#  ["I'm a die hard coffee lover who has had to drink decaf for the last 15 years.  I like a dark, robust coffee. This is absolutely the best and the closest there is to drinking a full bodied caffeinated coffee. Love it and will continue to buy it. I can also find it locally and when on sale it's less that he Amazon price. Good to shop around.",
#   1],
#  ['I bought 3 bags of coffee and when I received them, they were almost at their "freshest by" date.  It is not possible to use that much coffee in the space of a week!  This is the second time this has happened to me.  This is my favorite coffee but I will stop buying it through Amazon if you can\'t supply coffee that is almost past its best.',
#   0],
#  ["This is the best de-caf.  expensive but worth the price.  It can stand alone and hold it's own. sometimes, I use half decaf and half caf depending on the time of day.  For my money, Peet's is the best coffee any6way.  I look for a sale too.  I dk if Amazon has sales on this item.  TRY this decaf if you like French roast.  You will love it. You won't be able to tell the difference between the decaf and regular.  I mix it with other coffee too.",
#   1],
#  ["This is one of my all-time favorite brands of coffee! As an avid coffee drinker for the past 10 years, this is my go-to blend for my cup o' Joe! I highly recommend this - and the price is fairly comparable to your local grocery store. Very pleased!",
#   1],
#  ['great tasting for capuccino in an aeropress.', 1],
#  ["I can't drink coffee too late at night, but my husband has a cup after dinner every night.  Sometimes when I'm feeling jealous of his steaming cup of coffee, I have a cup too and regret it later when I can't get to sleep.  This has been my solution!  This decaf coffee has me fooled,  I can't tell a difference in the taste from this and the caffeinated variety.",
#   1],
#  ['Best decaf ever. At the time I bought it was around six dollars and now amazon isn’t selling anymore, so I’m going to assume it was old stock. Still tasted good- I use a 12 oz French press if that is information you need. If you see this at the store, stock up!',
#   1],
#  ["I'm always on the lookout for good strong coffee. So when I was on a trip to California and had my first cup of Peets Coffee at a cafe, I decided to order some via Amazon when I got back. Major Dickason's Blend is justifiably a dark/deep roast and did not disappoint. I prefer a dark roast but if you prefer a medium roast this is still a good option (I would just use a little less grounds) but the flavor is good either way. I am giving it 4 stars because for an inexpensive coffee this is a great option. I've spent a lot more money on other coffees that did not have the taste or quality that Peets Coffee has.",
#   1],
#  ["My son says that Peet's Coffee is the best coffee because it tastes so fresh.  It tends to be one of the most expensive grocery store brands so I usually buy it from Amazon for slightly less.  This was the first time I bought the light roast and my son liked it very much.",
#   1],
#  ['The best part of the coffee is no bitter aftertaste as in some.  I am not sure if it\'s worth the price or not though, and probably won\'t order again as I\'m not a "coffee snob".  LOL.  It is recommended online as one of the top 2 brands, so wanted to give it a try.',
#   1],
#  ['Really like this coffee. I was given a Dash Button as a present to be able to order this easily.Unfortunately the last two orders I’ve received were either past expiration date or within 2days of the expiration. I’m very disappointed in Amazon not sending fresh products.',
#   0],
#  ['Second time ordering; it is most definitely NOT "roast to order". Both bags were roasted 2 months prior to me receiving said bag(s) of coffee beans. Don\'t get me wrong, I quite enjoy this coffee. However, shouldn\'t put "roast to order" in the advertisement if it\'s not actually "roast to order"',
#   0],
#  ["I was a 'nothing but Starbucks' guy for about 15 years until I decided to try a bag of whole bean Peets Major Dickason's Blend coffee.It's impossible to go back now. If you enjoy full-flavored coffee that doesn't have a burnt taste, give this one a try.",
#   1],
#  ['Was hoping for something fresh for my espresso maker. Beans were over 2 months old, no way to know what you are going to get. I am sure if you are making drip coffe they would be fine, but picky espresso drinkers like me will keep looking.',
#   0],
#  ['This tastes like stale, supermarket brand coffee or what you find in your cup at a diner. Not all what I know Peet’s to be. Think ransid decaf but it’s not decaf. Such a disappointment. Returning for refund. Will stick with my usual vendor for authentic Peet’s coffee.',
#   0],
#  ["My wife and I really like this coffee.  It is dark, bold and smooth.  Not bitter.  It is our go to coffee.  PS you can also get at a major club chain owned by the walden's.",
#   1],
#  ['buying this by the case.  its taste and feel is excellent. a rich dark roast, hearty and a great wake up for the mornings.',
#   1],
#  ['Looove this coffee!', 1],
#  ["Peet's coffee is about the only decaf that actually has some flavor ... this is a dark roast and I think slightly darker than Peet's House Blend decaf.  Both tastes great and are you best choice if you like bold coffee taste but want to avoid the cafeine.",
#   1],
#  ["Very strong.  Great espresso forte dark.  The flavor is intense espresso.  Not as much crema.  after tasting this, I would opt down to medium roast next time.  It's a bit too strong for me.  The organic espresso at TJ is even stronger than this.",
#   1],
#  ["As always, Peet's is a tremendous coffe, then Amazon adds to the experience by delivering it to my door, free (with Prime)...Jim",
#   1],
#  ["So I've had this coffee in the past and all ways enjoyed it. So I ordered some. I received it and looked at the best by date and it was already past due. If it was whole beans I would not have thought anything of it but unfortunately it was pregrounded coffee. Was very irritated by this but it was the only coffee in the house. So I tried it. Tasted good. Almost like I remember but still. Why would you send me a bag of ground coffee that is past the freshest by date???????????????",
#   0],
# ...
#   0],
#  ['great coffee, great price', 1],
#  ['tasty for decaf', 1],
#  ['Love the taste of this coffee. It is a very fine grind.  Almost a powder.',
#   1],
#  ['i prefer a dark roast. i just did not like the taste of this one.', 0],
#  ['Coffee tastes amazing!', 1],
#  ['Love it!', 1],
#  ['Ordered in December and was roasted in September.', 0],
#  ['Good coffee and good price.', 1],
#  ['good strong coffee will buy more', 1],
#  ['We have a top of the line esspresso machine residing in our kitchen and the Italian Roast is a great way to start off the day.',
#   1],
#  ['Excellent coffee; and it costs less than what I pay at the supermarket.',
#   1],
#  ['Very Bitter. Does not taste like advertised.  Would not buy again.', 0],
#  ['love the taste, exactly like the one I tasted at peets', 1],
#  ['My husband loves this coffee!', 1],
#  ['really nice', 1],
#  ['Easy morning java!', 1],
#  ["got this for my sis for her birthday, she loves peet's coffee", 1],
#  ['Tastes too strong for my liking.', 0],
#  ['I like it because it is local.', 1],
#  ['Best coffee ever!', 1],
#  ['This is really good coffee! Might just be my favorite.', 1],
#  ['Awesome coffee. The best.', 1],
#  ['Flavorful robust morning wake up call brew', 1],
#  ["bold yet smooth, some aftertaste but it's so good it doesn't even matter",
#   1],
#  ['Amazing coffee to use for cold brew', 1],
#  ['Tastes wonderful', 1],
#  ['I like it.', 1],
#  ['Good brand. Always good', 1],
#  ['Love it', 1],
#  ['This is strong coffee similar to Starbucks which I like. The price was right, so I decided to take it for a test drive.',
#   1],
#  ['Flavorful & delicious!', 1],
#  ["Love Peet's Coffee!!!!", 1],
#  ['I love it.', 1],
#  ['YUM', 1],
#  ['Great coffee and price!', 1],
#  ['Good taste.', 1],
#  ['very very difficult to find but worth the wait. This wonderful coffee "fits" our Jura coffee maker and our tastes to perfection.Wish we could order more.',
#   1],
#  ['Very good coffee!', 1],
#  ['A great decaf coffee if you like a rich, hearty brew without caffeine.', 1],
#  ['I am serving in Afghanistan and ordered this product as an add on item on May 31, 2017 by June 7, 2017 I had the product. Taste great and very efficient on delivery.',
#   1],
#  ['Reliably delicious - Peets is an old favorite.', 1],
#  ["Love Peet's Big Bang, will buy more when it's on sale again", 1],
#  ['My favorite coffee!', 1],
#  ['Great coffee at my doorstep.', 1],
#  ["Peet's is the best.  This is a yummy coffee.", 1],
#  ["Pretty good coffee.  It has a mild flavor, not as bitter or strong as some of Peet's other blends.  It has a good chocolate flavor to it, although I add chocolate to my coffee anyway, so not sure how much of that is the coffee, but my mocha cappuccino still tasted good.  I also like how the grind is a bit on the finer side (not espresso grind) as I have a semi-automatic espresso machine with pressurized baskets that I use it in, so grind isn't as important, but this is more finely ground than other ground coffees I've purchased.",
#   1],
#  ['Yum.', 1],
#  ['Pleased with the coffee and purchase.', 1],
#  ['Great Coffee', 1],
#  ['BEst coffee', 1],
#  ['Great flavor and aroma.  Makes morning a whole lot easier', 1],
#  ['Great coffee, very strong.  Bought it for a good price on Amazon', 1],
#  ["Didn't know much about this company, but tried it out in the office.  It is now the coffee of choice!!!",
#   1],
#  ['as expected', 1],
#  ["The flavor like all Peet's coffee is fantastic. You would never know it is decaf.",
#   1],
#  ['Great coffee, the best', 1],
#  ["Love this coffee!!!  It totally met my expectations.  We first had Peets at our daughter's home in the Washington, DC area.  I searched several supermarkets in the area we live before finding it.  The flavor is very vibrant, very bold and rich!",
#   1],
#  ['Nice smooth coffee, always enjoy.  No bitter aftertaste.', 1],
#  ['Great coffee!!', 1],
#  ['Love Peets and this was a great way to get it!', 1],
#  ['Love the flavor.', 1],
#  ['It is always good', 1],
#  ['Was expired after I received it. The "freshest by date is 12/31/17 and the roasted date is 10/02/17. I received this and it was already expired.',
#   0],
#  ['Great taste and produce', 1],
#  ['good', 1],
#  ['This coffee has an excellent flavor, arrives fresh and aromatic. I can recommend it to anyone who likes a decaf coffee!',
#   1],
#  ['My favorite coffee!', 1],
#  ['Slightly cheaper when I buy from Amazon. I use this coffee almost every day in a French press and it comes out great.',
#   1],
#  ['Dark and rich', 1],
#  ['Another favorite of mine.', 1],
#  ['I have always used this coffee. Kinda  addictive', 1],
#  ['Great coffee', 1],
#  ['Great tasting coffee', 1],
#  ['Kind of spendy but the strongest decaf I have found.', 1],
#  ["Smells so good and tasty, not too bitter. You don't even add milk in it.",
#   1],
#  ['Excellent coffee at a good price. Delivery was fast.', 1],
#  ['I got it.', 0],
#  ['Excellent coffee, with that intense taste of dark French roast.  Packaged well and delivered on time.',
#   1],
#  ['great dark roast coffee', 1],
#  ['Was great! :)', 1],
#  ['I like', 1],
#  ['this price beats a grocery store', 1],
#  ['Excellent flavor!', 1],
#  ['Wonderful coffee!', 1],
#  ['Very good coffee.', 1],
#  ['Perfect balanced.', 1],
#  ["I am struggling to determine the best adjective to describe this decaf coffee, so I'll just say that it's the best cup I've ever had.  I'm sticking with Peet's Decaf French Roast.",
#   1],
#  ['our favorite coffee!!', 1],
#  ['my sister liked it', 1],
#  ['Biiter and not as smooth as I expected. I had to add sugar and more cream to balance the taste.  Certainly I am not buying this brand again much too strong. I  get anxious and my heart beats faster.',
#   0],
#  ['Great coffee, as expected great flavor, good price when buying online.', 1],
#  ['Great full bodied flavor', 1],
#  ['I have purchased this blend before and loved the bold richness of this coffee.  This purchase is a total disappointment.  It is very weak, no matter how many more tablespoons I add.  I tastes dry and stale.  Will not purchase this brand from Amazon.  Bummer.  This coffee will set in my emergency stash, only if I run out of the drinkable ones.',
#   0],
#  ['Way better than the other brands.', 1],
#  ['Coffee was overdue on 02/15/2018 。It arrived on the02/09/2018', 0],
#  ['I mean it,,,  Wonderful!', 1],
#  ["bright. bold. doesn't weigh heavy on the tongue", 1],
#  ["I order my ground coffee and k cups from Amazon all the time.  We love this coffee the best.  It's robust without any bitterness at all.",
#   1],
#  ['Super yummy dark coffee', 1],
#  ["Peet's is some of the best coffee I have ever had.", 1],
#  ['Got on time served at my coffee clutch with the girls.  Has a different taste but good.',
#   0],
#  ["Peet's Major Dickinson's dark roast is the best coffee around, beats Starbucks by a mile.  The price is great, also.",
#   1],
#  ['Great coffee.', 1],
#  ['Great coffee.', 1],
#  ['Love this coffee. Great robust taste, esp. for decaf! Will order again.',
#   1],
#  ['Best coffee ever!  Will order again.', 1],
#  ['nice coffee. peets does not disappoint me', 1],
#  ['best coffee', 1],
#  ['Great rich flavor.', 1],
#  ['yummy', 1],
#  ['This is great for making strong coffee in a french press!', 1],
#  ['Excellent coffee!!!', 1],
#  ['tasty', 1],
#  ['love this coffee', 1],
#  ['Great taste!', 1],
#  ['great bold taste', 1],
#  ['Bold flavor.', 1],
#  ['It really was great tasting.', 1],
#  ['great coffee', 1],
#  ["My absolute favorite! I'm very picky about my coffee.", 1],
#  ['Excellent coffee at a great price!', 1],
#  ['The best coffee in the world!!!! Thanks Amazon', 1],
#  ['Could of had a closer roasting date.', 0],
#  ['Great tasting coffee', 1],
#  ['Great as expected!', 1],
#  ['Delicious coffee!', 1],
#  ['Tasty.', 1],
#  ['Love the flavor so much! Will buy it again!', 1],
#  ['Great taste. Perfect for iced coffee.', 1],
#  ["Mocha Java decaf by Peet's is the bestDecaf-hope they are not discontinuing it!!",
#   1],
#  ['Delicious deep roast coffee. It is strong so you can use less grounds to make a full pot!',
#   1],
#  ['Excellent', 1],
#  ['Very surprised ! Much better that I thought it would be. Not bitter at all. I will buy this again . I am a Starbucks fan just thought I would try something new.',
#   1],
#  ['This coffee is great, but the price fluctuates quite a bit.  We bought a Breville Espresso Machine so all of a sudden we had a need for affordable, quality espresso beans.  I looked at several options on Amazon and settled on this.  With subscribe and save it was initially under $5 a package but since that initial purchase, it has fluctuated between $5-$7.  Despite the price increase, we still have reordered 15 to 20 times.  I love the quality and taste and will continue to order these beans until I find something cheaper.',
#   1],
#  ['Great coffee', 1],
#  ['Great flavor', 1],
#  ['My favorite.  And with Subscribe and Save it makes it even better.', 1],
#  ['Best coffee ever.', 1],
#  ["This coffee was really good.  Been trying to find it in New York, but haven't been able to.  I think it's worth the few extra bucks to get it delivered.  I've ordered twice now and each time the coffee comes fresh and still very aromatic.  Also, I think the caffeine content is pretty high, as I'm more awake on this brand then other brands like starbucks and fairway market brands.",
#   1],
#  ["Purchased this on August15 for $8.88 now it's over $14. Great coffee but can't justify the price increase.",
#   1],
#  ["Great, strong taste. Best at-home coffee I've had in a while. Just bought my second bag!",
#   1],
#  ['Delivered promptly and loved the coffee. Will order again.', 1],
#  ['Perfect coffee', 1],
#  ['It was really frish when it came and taste really good.', 1],
#  ['Great coffee!', 1],
#  ['Good coffee for the price', 1],
#  ['What I expected.', 1],
#  ["Richest, most full flavored decaf I've ever tasted.", 1],
#  ['Peets Coffee is the best decaf!', 1],
#  ['Favorite coffee hard to find in the stores', 1],
#  ['NIce and smooth.', 1],
#  ['I like all medium and dark varieties of this coffee', 1],
#  ["What's not to like...it's PEETs!", 1],
#  ['best coffee around', 1],
#  ['the best coffee', 1],
#  ['A great deal when the price drops below $8 with subscribe and save.  Watch the price fluctuations though.',
#   1],
#  ["The best dark roast blend I've had this side of the Atlantic!", 1],
#  ['Always good and arrived in good shape', 1],
#  ['Major Dickinsons blend is awesome.', 1],
#  ['Delicious!', 1],
#  ['Excellent', 1],
#  ['Very full taste and great aroma when brewing.', 1],
#  ['Great tasting coffee!', 1],
#  ['the best', 1],
#  ['Love Peets!', 1],
#  ['Great coffee', 1],
#  ['Really nice, mild and flavorful coffee.', 1],
#  ['Yummy', 1],
#  ['Nice taste', 1],
#  ["For some reason 8 O'Clock coffee is not currently supplying my favorite whole bean Italian roast lately, so I tried this version. Frankly it is not very robust and lacks full bodied flavor. I didn't even finsh the whole package before I switched to Starbucks French Roast instead. That one is pretty good.Peter",
#   0],
#  ['Great coffee', 1],
#  ['fresh', 1],
#  ['Good tasting coffee', 1],
#  ['Excellent!', 1],
#  ['Great coffee!', 1],
#  ["The best coffee I've tried.", 1],
#  ['Best coffee in world', 1],
#  ['This had great flavor, especially for a decaf.', 1],
#  ['Delicious, Rich, full bodied coffee. Among the very best!', 1],
#  ['I ordered two orders and both times the coffee had no scent....just called peets in berkeley , they shipped me 4 bags and it is great....the original great coffee....before starbucks....no comparison.....PEETS is the very best....',
#   0],
#  ['Yum', 1],
#  ['when I stayed in SF last yr, I exprienced this coffee, I was so touched by it. Since that time, I have ordered it many times,',
#   1],
#  ['Great tasting coffee - full bodied.', 1],
#  ["Peet's Domingo  is a perfect medium roast.  As I get older the taste of the dark roasts are not as appealing as they once were but not quite ready for the weaker light roasts.  This roast is not bitter and has a nice after taste. I find this roast slightly better than Starbucks Pike roast. I highly recommend this coffee.",
#   1],
#  ["I thought coffee was coffee until I tried Peet's. There is no comparison! Thank you for a bright start to my day.",
#   1],
#  ['This is great coffee', 1],
#  ["bought different kinds of coffee for 40 years.  even 70.00 a lb Jamaica Blue Mountain.....it was a gift but still not what I was looking for.  Saw Peet's in the store for the 1st time a few years ago and it ended my search.  Absolutly love it.  There is no better coffee for my money.",
#   1],
#  ['Very good. Will purchse again', 1],
#  ['love the smooth taste.', 1],
#  ['My rating is for the Costa Rica blend. It was harsh, bitter, absolutely disgusting. In addition to the poor taste, the coffee also tasted as if the grounds were either really old, or hadn’t been properly sealed despite the bag being closed.I normally like peets coffee, but this blend was atrocious. Zero notes of molasses, black currant, or any sweetness whatsoever.',
#   0],
#  ['The absolute best in coffee...full body and flavor without being overpowering',
#   1],
#  ['The coffee was as expected BUT THE BAG HAD BEEN SLIT AND PLACED INSIDE ANOTHER PLASTIC BAG. I really think that one should have been trashed and replaced with an intact bag. My poor husband was trying to help and he had already made me two pots of coffee when he told me what had happened. NOT HAPPY',
#   0],
#  ['Big Bang was not to my liking. I brewed it many ways and with various ratios of water to grounds and never hit a sweet spot. It was without any memorable flavor and was best with whole milk added. Thst is not how I like my coffee. Black it was awful.',
#   0],
#  ['Great coffee!', 1],
#  ['Everybody loves my Mr. Peets coffee.', 1],
#  ['Delicious! The price was as good as buying in the grocery store but, shipped to your door!  Very good flavor and I will definitely buy it again.',
#   1],
#  ['Amazing', 1],
#  ['trial, it was good', 1],
#  ['Thank you Amazon for the subscribe and saving (is that a verb now?) Peets Italian Roast! It is the energy source in our house and nothing else will do. Unfortunately it is an expensive habit, but SnS allows us to spend $6.99 a bag! Yes, thank you...We will take 4 every month. Thank you. Thank you!',
#   1],
#  ['seller excellent, goods qualitative', 1],
#  ['Not very strong for my taste. For a reference I am used to having Starbucks French Roast. This is not nearly as strong, beans are brown compared to SB black. I ended up mixing the beans in with SB, but wont be purchasing this again. Still looking for a strong SB FR replacement.',
#   0],
#  ['We wanted to like this coffee very much. It was suggested to us by a former boutique wine and coffee shop employee, and we have always liked her advice. It is just not tasty; the taste would make me want to give up coffee.',
#   0],
#  ['I did not enjoy this coffee at all. Peet’s is usually a safe bet, but I would not recommend this flavor at all. I couldn’t figure out why the flavor was so harsh and not flavorful. I think maybe the citrus blend makes it so acidic. I’m not really an expert, so I don’t know. I’m looking forward to trying their other blends.',
#   0],
#  ['Its always just perfect.', 1],
#  ['Just great coffee!', 1],
#  ['Great coffee!!', 1],
#  ['Perfect!!!!', 1],
#  ["I am a newer coffee drinker and I don't want to always habe to add items to coffee to drink it. This is not very bitter and it does not have a burnt taste as some coffees do so I can deink it black and for a treat add in extras if wanted",
#   1],
#  ['Great price', 1],
#  ["Given the price per pound and the bland, but heavy flavor, I would not buy this again. The grind is very powdery, so you're going to get an extended brew process since the water pools in the filter, and there's absolutely nothing special about the flavor. Seriously, there are much less expensive coffees that are way better.",
#   0],
#  ['Great', 1],
#  ["It's Peets. What else needs be said.", 1],
#  ['Great coffee, smooth', 1],
#  ...]

# %% [markdown]
# #### PASO3: LIMPIEZA Y TRANSFORMACION
# * Transformar oraciones en vectores de palabras
# * Se removen palabras muy pequeñas
# * Se generalizan familias de palabras: *Stemming and lemmatization* https://nlp.stanford.edu/IR-book/html/htmledition/stemming-and-lemmatization-1.html
# * Se remueven palabras que no aportan mayor significado: stopwords
# * TODO ESTO DERIVA EN CREAR UN DICCIONARIO DE PALABRAS CLAVE

# %%
''' CONVIERTE UN COMENTARIO EN UN VECTOR DE PALABRAS CLAVE '''
def tokenizer(s):
    s = s.lower() # downcase    
    tokens = nltk.tokenize.word_tokenize(s) # divide el texto en palabras (tokens)
    tokens = [t for t in tokens if len(t) > 3] # remueve palabras de menos de 3 letras
    tokens = [wordnet_lemmatizer.lemmatize(t) for t in tokens] # reduce las palabras a su base
    tokens = [t for t in tokens if t not in stopwords] # remueve palabras que no aportan valor
    return tokens

# %%
''' SE CREA UNA MATRIZ DE PALABRAS RELACIONADAS A CADA REVIEW '''
def tokens_to_vector(tokens, label):
    x = np.zeros(len(word_index_map) + 1) 
    for t in tokens:
        i = word_index_map[t]
        x[i] += 1
    x = x / x.sum() #Se normalizan las variables para que sean comparables 
    x[-1] = label
    return x

# %%
''' SE CREA UN DICCIONARIO DE PALABRAS CON LOS TOKENS DE TODOS LOS COMENTARIOS '''
all_reviews = load_reviews()
all_reviews_ = []
current_index = 0

for review in all_reviews:
    tokens = tokenizer(review[0])    
    if tokens:
        for token in tokens:
            if token not in word_index_map:
                word_index_map[token] = current_index
                current_index += 1    
        all_reviews_.append(review)

all_reviews = all_reviews_
print("tamaño del diccionario de palabras:",len(word_index_map))
# Out:
# tamaño del diccionario de palabras: 2572

# %%
word_index_map
# Out:
# {'roasted': 0,
#  'bean': 1,
#  'reason': 2,
#  'lately': 3,
#  'time': 4,
#  'roasting': 5,
#  'batch': 6,
#  'morning': 7,
#  'mean': 8,
#  'grinding': 9,
#  'perking': 10,
#  'warm': 11,
#  'optimal.so': 12,
#  'hassle': 13,
#  'occasional': 14,
#  'particular': 15,
#  'taste': 16,
#  'shopped': 17,
#  'reliable': 18,
#  'substitute.the': 19,
#  'discovered': 20,
#  'money': 21,
#  'mediocre': 22,
#  'lousy': 23,
#  'eventually': 24,
#  'managed': 25,
#  'tofind': 26,
#  'primo': 27,
#  'stuff': 28,
#  'this': 29,
#  'highly': 30,
#  'recommend.i': 31,
#  'floral': 32,
#  'note': 33,
#  'finish': 34,
#  'absinthe': 35,
#  'nonsense': 36,
#  'coffee': 37,
#  'dark': 38,
#  'rich': 39,
#  'bitter': 40,
#  'guy': 41,
#  'ought': 42,
#  'maybe': 43,
#  'exactly': 44,
#  'looking': 45,
#  'feel': 46,
#  'paid': 47,
#  'premium': 48,
#  'price': 49,
#  'mind': 50,
#  'book': 51,
#  'history': 52,
#  'starbucks': 53,
#  'mention': 54,
#  'model': 55,
#  'product': 56,
#  'peet': 57,
#  'care': 58,
#  'flavor': 59,
#  'complexity': 60,
#  'etc.': 61,
#  'wrong': 62,
#  'welllllll': 63,
#  'local': 64,
#  'house': 65,
#  'doe': 66,
#  'amazing': 67,
#  'roaster': 68,
#  'expertise': 69,
#  'equipment': 70,
#  'scientist': 71,
#  'artist': 72,
#  'supposedly': 73,
#  'over-roasts': 74,
#  'consistency': 75,
#  'little': 76,
#  'speedy': 77,
#  'anxiety': 78,
#  'causing': 79,
#  'vintner': 80,
#  'wine': 81,
#  'true': 82,
#  'connoisseur': 83,
#  'enjoy': 84,
#  'suggestion': 85,
#  'shopping': 86,
#  'deal': 87,
#  'strong': 88,
#  'original': 89,
#  'major': 90,
#  'dickason': 91,
#  'blend': 92,
#  'late': 93,
#  '1980': 94,
#  'then': 95,
#  'real': 96,
#  'treat': 97,
#  'crop': 98,
#  'change': 99,
#  'found': 100,
#  'favorite': 101,
#  'directly': 102,
#  'past': 103,
#  'amazon.i': 104,
#  'call': 105,
#  'incarnation': 106,
#  'tiny': 107,
#  'acidic': 108,
#  'balance': 109,
#  'acidity': 110,
#  'usually': 111,
#  'scoop': 112,
#  'french': 113,
#  'roast': 114,
#  'fuller': 115,
#  'body': 116,
#  'smoothness': 117,
#  'perfect': 118,
#  'love': 119,
#  'full-bodied': 120,
#  'richness': 121,
#  'them.i': 122,
#  'read': 123,
#  'review': 124,
#  'receiving': 125,
#  'stale': 126,
#  'week': 127,
#  'date': 128,
#  'day': 129,
#  'fall': 130,
#  '2017': 131,
#  'advise': 132,
#  'prime': 133,
#  'chat': 134,
#  'instead': 135,
#  'negative': 136,
#  'comment': 137,
#  'wonderful': 138,
#  'customer': 139,
#  'service': 140,
#  'rep': 141,
#  'matter': 142,
#  'shame': 143,
#  'tried': 144,
#  'fresh': 145,
#  'robust': 146,
#  'compared': 147,
#  'bagged': 148,
#  'weaker': 149,
#  'reduce': 150,
#  'watery': 151,
#  'le': 152,
#  'espresso': 153,
#  'fleeting': 154,
#  'event': 155,
#  'result': 156,
#  'consistent.while': 157,
#  'drink': 158,
#  'constantly': 159,
#  'week.i': 160,
#  'dedicated': 161,
#  'drinker': 162,
#  'home': 163,
#  'saying': 164,
#  'however': 165,
#  'opinion': 166,
#  'cafe': 167,
#  'restaurant': 168,
#  'disappointed': 169,
#  'loyal': 170,
#  'dependent': 171,
#  'things:1.': 172,
#  'quality': 173,
#  'beans2': 174,
#  'equipment3': 175,
#  'techniquestarting': 176,
#  'simple': 177,
#  'screw': 178,
#  'cover': 179,
#  'machine': 180,
#  'upgraded': 181,
#  'couple': 182,
#  'twenty': 183,
#  'started': 184,
#  'standard': 185,
#  'krups': 186,
#  'electric': 187,
#  'spice': 188,
#  'grinder': 189,
#  'grind': 190,
#  'consistent': 191,
#  'else': 192,
#  'spices.for': 193,
#  'burr': 194,
#  'reading': 195,
#  'kindle': 196,
#  'e-books': 197,
#  'scouring': 198,
#  'obsessed': 199,
#  'improving': 200,
#  'technique': 201,
#  'surprise': 202,
#  'wife': 203,
#  'rancillio': 204,
#  '.along': 205,
#  'amazon': 206,
#  'shipping': 207,
#  'solid': 208,
#  'performer': 209,
#  'period': 210,
#  'success': 211,
#  'failure': 212,
#  'smooth': 213,
#  'day-to-day': 214,
#  'coffee.i': 215,
#  'mistake': 216,
#  'ground': 217,
#  'month': 218,
#  'using': 219,
#  'moka': 220,
#  'coarse': 221,
#  'immediately': 222,
#  'typically': 223,
#  'locally': 224,
#  'store': 225,
#  'quickly': 226,
#  'delivered': 227,
#  'bella': 228,
#  'finca': 229,
#  'henry': 230,
#  'francisco': 231,
#  'atomic': 232,
#  'beverly': 233,
#  'recall': 234,
#  'sold': 235,
#  'gocoffeego': 236,
#  'charge': 237,
#  'expensive': 238,
#  'normal': 239,
#  'budget': 240,
#  'enjoyed': 241,
#  'kicking': 242,
#  'horse': 243,
#  'kick': 244,
#  'grizzly': 245,
#  'claw': 246,
#  'power': 247,
#  'mentioned': 248,
#  'reviewer': 249,
#  'inconsistent': 250,
#  'disappointing': 251,
#  'recently': 252,
#  'doesn': 253,
#  'eight': 254,
#  'otherwise': 255,
#  'it.as': 256,
#  'preference': 257,
#  'steel': 258,
#  'vacuumed': 259,
#  'canister': 260,
#  'counter': 261,
#  'measuring': 262,
#  '15.6': 263,
#  'graham': 264,
#  'fine': 265,
#  'relative': 266,
#  'targeted': 267,
#  'pour': 268,
#  'firm': 269,
#  'five-point': 270,
#  'tamping': 271,
#  'method': 272,
#  'preheated': 273,
#  'saucer': 274,
#  'strive': 275,
#  'honey': 276,
#  'colored': 277,
#  'stream': 278,
#  'plenty': 279,
#  'crèma': 280,
#  'holy': 281,
#  'grail': 282,
#  'world': 283,
#  'delectable': 284,
#  'brew': 285,
#  'captured': 286,
#  'marked': 287,
#  'shot': 288,
#  'glass': 289,
#  'praying': 290,
#  'moment': 291,
#  'talk': 292,
#  'nicely': 293,
#  'cheer': 294,
#  'line': 295,
#  'walk': 296,
#  'attempt': 297,
#  'doppio': 298,
#  'ounce': 299,
#  'nice': 300,
#  'received': 301,
#  'package': 302,
#  '12/20': 303,
#  '9/18': 304,
#  '12/17': 305,
#  'fresher': 306,
#  'discount': 307,
#  'addon': 308,
#  'listing': 309,
#  'dickerson': 310,
#  'blend.i': 311,
#  'convert': 312,
#  'ruined': 313,
#  'medium': 314,
#  'snob': 315,
#  'willing': 316,
#  'spend': 317,
#  'website': 318,
#  'surprised': 319,
#  'complex': 320,
#  'satisfying': 321,
#  'check': 322,
#  'cautious': 323,
#  'knowing': 324,
#  'tasted': 325,
#  'foundation': 326,
#  'comparison': 327,
#  'happily': 328,
#  'trouble': 329,
#  'hitting': 330,
#  'minimum': 331,
#  'shop': 332,
#  'trying': 333,
#  'roasters/blends': 334,
#  'choice': 335,
#  'write': 336,
#  'participation': 337,
#  'vine': 338,
#  'voice': 339,
#  'program': 340,
#  'free': 341,
#  'item': 342,
#  'exchange': 343,
#  'unbiased': 344,
#  'extremely': 345,
#  'infrequently': 346,
#  'absolutely': 347,
#  'remember': 348,
#  'experience': 349,
#  'concerned': 350,
#  'coffee.the': 351,
#  'sense': 352,
#  'smell': 353,
#  'closely': 354,
#  'tied': 355,
#  'emotional': 356,
#  'reaction': 357,
#  'frying': 358,
#  'bacon': 359,
#  'bakery': 360,
#  'fragrant': 361,
#  'blooming': 362,
#  'rose': 363,
#  '*good': 364,
#  'conjures': 365,
#  'head': 366,
#  'feeling': 367,
#  'emotion': 368,
#  'pleasure': 369,
#  'wondering': 370,
#  'imaginable': 371,
#  'nose': 372,
#  "dickason's.it": 373,
#  'worth': 374,
#  'mentioning': 375,
#  'k-cups': 376,
#  'pressed': 377,
#  'keurig': 378,
#  'ninja': 379,
#  'truth': 380,
#  'cheap': 381,
#  'dollar': 382,
#  'barista-inspired': 383,
#  'heaven': 384,
#  'coffee-brewing': 385,
#  'hope': 386,
#  'duplicate.peet': 387,
#  'exist': 388,
#  'sponsor': 389,
#  'kylo': 390,
#  'order.if': 391,
#  'bag': 392,
#  'buckle': 393,
#  'finest': 394,
#  'tastiest': 395,
#  'available': 396,
#  'nearly': 397,
#  'average': 398,
#  'decaf': 399,
#  'unleaded': 400,
#  'searched': 401,
#  'it.nothing': 402,
#  'folgers': 403,
#  'gevalia': 404,
#  'seattle': 405,
#  'community': 406,
#  'close': 407,
#  'ripe': 408,
#  'deeply': 409,
#  'rounded': 410,
#  'profile': 411,
#  'scarcely': 412,
#  'acid': 413,
#  'character': 414,
#  'fortitude': 415,
#  'substitute': 416,
#  'seriously': 417,
#  'no-compromise': 418,
#  'updated': 419,
#  'april': 420,
#  '2018': 421,
#  'stop': 422,
#  'february': 423,
#  'purchased': 424,
#  'thinking': 425,
#  'discontinue': 426,
#  'brought': 427,
#  'wasted': 428,
#  'buying': 429,
#  'trashed': 430,
#  'them.by': 431,
#  'purchase': 432,
#  'friend': 433,
#  'tell': 434,
#  'drinking': 435,
#  'sneaky': 436,
#  'water': 437,
#  'processed': 438,
#  'notice': 439,
#  'tasting': 440,
#  'urge': 441,
#  'popular': 442,
#  'didn': 443,
#  'taste-': 444,
#  'realize': 445,
#  'healthier': 446,
#  'hand': 447,
#  'superior': 448,
#  'deep': 449,
#  'aeropress': 450,
#  'maker': 451,
#  'tbsp': 452,
#  'freshly': 453,
#  'roughly': 454,
#  'gram': 455,
#  '205°f': 456,
#  'excellent': 457,
#  'subscribe': 458,
#  'save': 459,
#  'monthly': 460,
#  'staple': 461,
#  'kidding': 462,
#  'aficionado': 463,
#  'gambit': 464,
#  'short': 465,
#  'pound': 466,
#  'gourmet': 467,
#  'beans.i': 468,
#  'seen': 469,
#  'oil': 470,
#  'soaking': 471,
#  'aroma': 472,
#  'phenomenal': 473,
#  'grade': 474,
#  'regular': 475,
#  'press': 476,
#  'filled': 477,
#  'refillable': 478,
#  'filter': 479,
#  'wowza': 480,
#  'getting': 481,
#  'time.the': 482,
#  'beat': 483,
#  'sumatra': 484,
#  'easily': 485,
#  'trump': 486,
#  'brand': 487,
#  'allegedly': 488,
#  'organic': 489,
#  'food': 490,
#  'lingers': 491,
#  'probably': 492,
#  'tongue': 493,
#  'cup.if': 494,
#  'cream': 495,
#  'sugar': 496,
#  'person': 497,
#  'bother': 498,
#  'appreciate': 499,
#  'difference': 500,
#  'literally': 501,
#  'dozen': 502,
#  'hard': 503,
#  'finding': 504,
#  'palette': 505,
#  'velvety': 506,
#  'acidy': 507,
#  'bite': 508,
#  'daily': 509,
#  'yourself': 510,
#  'usual': 511,
#  'cold': 512,
#  'toddy': 513,
#  'recommended': 514,
#  'extra': 515,
#  'unfortunately': 516,
#  'unusually': 517,
#  'hour': 518,
#  'process': 519,
#  'left': 520,
#  'brewed': 521,
#  'discernible': 522,
#  'plus': 523,
#  'worst': 524,
#  'military': 525,
#  'searching': 526,
#  'except': 527,
#  'eaten': 528,
#  'recycled': 529,
#  'civet': 530,
#  'sort': 531,
#  'burned': 532,
#  'edge': 533,
#  'finally': 534,
#  'maj.': 535,
#  'dickenson': 536,
#  'bland': 537,
#  'savor': 538,
#  'hands-down': 539,
#  'lighter': 540,
#  'pretty': 541,
#  'similar': 542,
#  'veranda': 543,
#  'totally': 544,
#  'colombia': 545,
#  'luminosa': 546,
#  'completely': 547,
#  'brighter': 548,
#  'bang': 549,
#  'stock': 550,
#  'recurring': 551,
#  'shipped': 552,
#  'picked': 553,
#  'kroger': 554,
#  'bring': 555,
#  'taking': 556,
#  'account': 557,
#  'none': 558,
#  'dang': 559,
#  'decaffeinated': 560,
#  'bold': 561,
#  'intense': 562,
#  'latin': 563,
#  'american': 564,
#  'smoky': 565,
#  'decided': 566,
#  'caffeine': 567,
#  'headache': 568,
#  'reasonably': 569,
#  'priced': 570,
#  'grocery': 571,
#  'school': 572,
#  'percolator': 573,
#  'stove': 574,
#  'seven': 575,
#  'failing': 576,
#  'inch': 577,
#  'closer': 578,
#  'diabetes': 579,
#  'run': 580,
#  'story': 581,
#  'break': 582,
#  'bank': 583,
#  'balanced': 584,
#  'strange': 585,
#  'aftertaste': 586,
#  'version': 587,
#  'darkest': 588,
#  'truly': 589,
#  'traditional': 590,
#  'style': 591,
#  'dark-to-medium': 592,
#  'superb': 593,
#  'combination': 594,
#  'bright': 595,
#  'varying': 596,
#  'strength': 597,
#  'lightest': 598,
#  'delightfully': 599,
#  '10/5/17': 600,
#  "'best": 601,
#  '10/11/17': 602,
#  'happened': 603,
#  'careful': 604,
#  'purchasing': 605,
#  'peets': 606,
#  'college': 607,
#  'beautifully': 608,
#  'crema': 609,
#  'perfectly': 610,
#  'considering': 611,
#  'senior': 612,
#  'magical': 613,
#  'mocha': 614,
#  'java': 615,
#  'brewing': 616,
#  'experienced': 617,
#  'people': 618,
#  'benefit': 619,
#  'refined': 620,
#  'specific': 621,
#  'perspective': 622,
#  'particularly': 623,
#  'palate': 624,
#  'health': 625,
#  'weird': 626,
#  'duck': 627,
#  'doctor': 628,
#  'researcher': 629,
#  'advocate': 630,
#  'darker': 631,
#  'sufferer': 632,
#  'sick': 633,
#  'regardless': 634,
#  'horrible': 635,
#  'personally': 636,
#  'dislike': 637,
#  'smokiness': 638,
#  'whatever': 639,
#  'contrary': 640,
#  'prevailing': 641,
#  'wisdom': 642,
#  'affect': 643,
#  'slightest': 644,
#  'figure': 645,
#  'pleased': 646,
#  'stomach': 647,
#  'all.i': 648,
#  'starting': 649,
#  'soon': 650,
#  'towards': 651,
#  'light': 652,
#  'flavorful': 653,
#  'aromatic': 654,
#  'roasty': 655,
#  'palpable': 656,
#  'hurt': 657,
#  'match': 658,
#  'for.it': 659,
#  'mellow': 660,
#  'despite': 661,
#  'lack': 662,
#  'envision': 663,
#  'over-roasted': 664,
#  'sometimes': 665,
#  'roastier': 666,
#  'labeled': 667,
#  'mild': 668,
#  'unless': 669,
#  'extract': 670,
#  'minute': 671,
#  'supposed': 672,
#  'explaining': 673,
#  'moderately': 674,
#  'darned': 675,
#  'faintly': 676,
#  'blueberry': 677,
#  'claimed': 678,
#  'ethiopian': 679,
#  'super': 680,
#  'natural': 681,
#  'inclusion': 682,
#  'centered': 683,
#  'hint': 684,
#  'pleasingly': 685,
#  'extraction': 686,
#  'non-boiled': 687,
#  'beginning': 688,
#  'steam': 689,
#  'precise': 690,
#  'thermally': 691,
#  'earthy': 692,
#  'definitely': 693,
#  'stronger': 694,
#  'imo.if': 695,
#  'decent': 696,
#  'pleasing': 697,
#  'especially': 698,
#  'mildly': 699,
#  'citrus': 700,
#  'tingle': 701,
#  'moving': 702,
#  'lightness': 703,
#  'scale': 704,
#  'downside': 705,
#  'presence': 706,
#  'gentle': 707,
#  'guess': 708,
#  'it.oh': 709,
#  'depending': 710,
#  'help': 711,
#  'mine': 712,
#  "'cook": 713,
#  'illustrated': 714,
#  'rated': 715,
#  'lover': 716,
#  'supermarket': 717,
#  '37.50': 718,
#  '-ounce': 719,
#  '13.95': 720,
#  '1-pound': 721,
#  'bag.i': 722,
#  'chocolate': 723,
#  'toast': 724,
#  'remarkable': 725,
#  'odor': 726,
#  'renown': 727,
#  'northwest': 728,
#  'gaining': 729,
#  'foothold': 730,
#  'northeast': 731,
#  'daughter': 732,
#  'sale': 733,
#  'bulk': 734,
#  'domingo': 735,
#  'buy.highly': 736,
#  'prisrob': 737,
#  '03-20-13': 738,
#  'obviously': 739,
#  'stuck': 740,
#  'heard': 741,
#  'sevverely': 742,
#  'burnt': 743,
#  'tossed': 744,
#  'trash': 745,
#  'thank': 746,
#  'iced': 747,
#  'originally': 748,
#  'paying': 749,
#  'luckily': 750,
#  'loved': 751,
#  'recommend': 752,
#  'sake': 753,
#  'vacation': 754,
#  'fast': 755,
#  'forward': 756,
#  'easier': 757,
#  'elected': 758,
#  'happy': 759,
#  'awake': 760,
#  'alternative': 761,
#  'waiting': 762,
#  'shoot': 763,
#  'remained': 764,
#  'deal.the': 765,
#  'normally': 766,
#  'arrive': 767,
#  'non-vacume': 768,
#  'floppy': 769,
#  'rigid': 770,
#  'drip': 771,
#  'fourth': 772,
#  'huge': 773,
#  'fluctuation': 774,
#  'annoying': 775,
#  'putting': 776,
#  'pricing': 777,
#  'enjoying': 778,
#  'frequent': 779,
#  'carry': 780,
#  'glad': 781,
#  'plain': 782,
#  'issue': 783,
#  'freshness': 784,
#  'occasionally': 785,
#  'burn': 786,
#  'too-hot': 787,
#  'factor': 788,
#  'sensitive': 789,
#  'overly': 790,
#  'pair': 791,
#  'delicious': 792,
#  'non-dairy': 793,
#  'creamer': 794,
#  'hario': 795,
#  'fancy': 796,
#  'report': 797,
#  'd-mn': 798,
#  'agent': 799,
#  'dale': 800,
#  'cooper': 801,
#  'like.update': 802,
#  '4/12/18': 803,
#  'fantastic': 804,
#  'funsies': 805,
#  'hemp': 806,
#  'takeya': 807,
#  'pitcher': 808,
#  'hold': 809,
#  'frozen': 810,
#  'changed': 811,
#  'flavorless': 812,
#  'thin': 813,
#  'coffee-water': 814,
#  'ratio': 815,
#  'slightly': 816,
#  'noticeably': 817,
#  'image': 818,
#  'google': 819,
#  'junk': 820,
#  'authentic': 821,
#  'offering': 822,
#  'source': 823,
#  'long-lasting': 824,
#  'going.the': 825,
#  'prefer': 826,
#  'finely': 827,
#  'turkish': 828,
#  'slowly': 829,
#  'now.this': 830,
#  'covfefe': 831,
#  'door': 832,
#  'backstock': 833,
#  'essential': 834,
#  'sealed': 835,
#  'dating': 836,
#  'shopper': 837,
#  'variation': 838,
#  'market': 839,
#  'watching': 840,
#  'stocking': 841,
#  'online': 842,
#  'lock': 843,
#  'substantially': 844,
#  'season': 845,
#  'grocer': 846,
#  'opener': 847,
#  'rotation': 848,
#  'folger': 849,
#  'penny': 850,
#  'great-tasting': 851,
#  'remembered': 852,
#  'leaning': 853,
#  'acquired': 854,
#  'veering': 855,
#  'believe': 856,
#  'reminds': 857,
#  'yeti': 858,
#  'imperial': 859,
#  'stout': 860,
#  'iykwimaityd': 861,
#  'ruta': 862,
#  'maya': 863,
#  'husband': 864,
#  'fill': 865,
#  'pod': 866,
#  'cup': 867,
#  'describe': 868,
#  'nutty': 869,
#  'wake': 870,
#  'ghirardelli': 871,
#  'personal': 872,
#  'dirty': 873,
#  'dunkin': 874,
#  'donut': 875,
#  'receive': 876,
#  'worry': 877,
#  '10-cup': 878,
#  'pot': 879,
#  'travel': 880,
#  'single': 881,
#  'cone': 882,
#  'wherever': 883,
#  'missing': 884,
#  'bodied': 885,
#  'selling': 886,
#  'client': 887,
#  'offered': 888,
#  'anyway': 889,
#  'incredible': 890,
#  'costco': 891,
#  'sell': 892,
#  'mistobox': 893,
#  'send': 894,
#  'ton': 895,
#  'broke.even': 896,
#  'buck': 897,
#  'kimbo': 898,
#  'italy': 899,
#  'bitterness': 900,
#  'potential': 901,
#  'dialed': 902,
#  'vintage': 903,
#  'olympia': 904,
#  'cremina': 905,
#  'lever': 906,
#  'pull': 907,
#  'lower': 908,
#  'temperature': 909,
#  'describing': 910,
#  'allows': 911,
#  'scene': 912,
#  'type': 913,
#  'pete': 914,
#  'range': 915,
#  'blow': 916,
#  'expressso': 917,
#  'hamilton': 918,
#  'beach': 919,
#  '49981a': 920,
#  'serve': 921,
#  'sweetened': 922,
#  'half': 923,
#  'froth.i': 924,
#  '12oz': 925,
#  'avoiding': 926,
#  'returned': 927,
#  'brother': 928,
#  'november': 929,
#  'kirkland': 930,
#  'bought': 931,
#  'pre-ground': 932,
#  'look': 933,
#  'wish': 934,
#  'forget': 935,
#  'settle': 936,
#  'gab..': 937,
#  'smelled': 938,
#  'expires': 939,
#  'unacceptable': 940,
#  'vanilla': 941,
#  'fruity': 942,
#  'crisp': 943,
#  'believed': 944,
#  'inverted': 945,
#  'steal': 946,
#  'different/bad': 947,
#  'pack': 948,
#  'arrived': 949,
#  'condition': 950,
#  'grain': 951,
#  'awful': 952,
#  'one.i': 953,
#  'tasty': 954,
#  'caffeinated': 955,
#  'lot': 956,
#  'unlike': 957,
#  'shocked': 958,
#  'legal': 959,
#  'trader': 960,
#  'wintry': 961,
#  'jacked': 962,
#  'productive': 963,
#  'heart': 964,
#  'stand': 965,
#  'all-around': 966,
#  'cold-brew': 967,
#  'option': 968,
#  'explore': 969,
#  'widely': 970,
#  'competitive': 971,
#  'brazil': 972,
#  'mina': 973,
#  'naturais': 974,
#  'reviewsat': 975,
#  'could.i': 976,
#  'etc.but': 977,
#  'gotten': 978,
#  'nope.i': 979,
#  'demote': 980,
#  'expiration': 981,
#  '12/31/17': 982,
#  'christmas': 983,
#  'gift': 984,
#  'doubt': 985,
#  'sour': 986,
#  'cooled': 987,
#  'noticed': 988,
#  'cool': 989,
#  'stay': 990,
#  'start': 991,
#  'subscribed': 992,
#  'delivery': 993,
#  'iced-coffee': 994,
#  'deeper': 995,
#  'maxwell': 996,
#  'grinded': 997,
#  'expect': 998,
#  'yeah': 999,
#  ...}

# %%
N = len(all_reviews)
data = np.zeros((N, len(word_index_map) + 1)) #La matriz es de tamaño N reviews x D+1 palabras
i = 0
            
for review in all_reviews:
    tokens = tokenizer(review[0])
    xy = tokens_to_vector(tokens,review[1])
    data[i,:] = xy
    i += 1

# %% [markdown]
# #### PASO4: ALMACENAMIENTO DE LA INFORMACION

# %%
df_reviews = pd.DataFrame(all_reviews).reset_index()
df_reviews.columns = ['Index','Comment','Positive']

# %%
#ALGUNOS REVIEWS POSITIVOS
df_reviews[df_reviews.Positive == 1].head()
# Out:
#    Index  \
# 0      0
# 1      1
# 2      2
# 3      3
# 5      5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Comment  \
# 0  For years I roasted my own beans and the only reason I don't do it much lately is because I just don't ever have the time. So you end up too often roasting a batch of beans at 6 am so you can have a morning cup. Which means you're grinding and perking warm beans which is not optimal.So too much of a hassle and while I still do the occasional batch to my own particular taste, I have shopped around for a reliable substitute.The first thing I discovered is that you can pay a lot of money for so...
# 1  After all these years, still the best coffee you can get.  Keep in mind that even the book about the history of Starbucks has a mention of how they wanted to model their product after Peet's... and Peet's just cares so much about flavor, roasting, complexity, etc., etc. that you can't go wrong.  You might say "welllllll, my local coffee house does an amazing job", but you know what, most local coffee roasters still don't have the expertise or the equipment, or the scientists and artists behi...
# 2  This is a good, strong coffee. It's not the original Major Dickason's Blend that put Peet's on the map in the late 1980's though. Back then the beans were quite rich and a real treat. As with any coffee bean over the years, crops change, so beans are not quite the same. I have found this to be true when ordering any of my favorites directly from Peet's over the past few years or via Amazon.I wouldn't call the newest incarnation of this blend bitter, but it is a tiny bit acidic. To balance th...
# 3  At times, making a good espresso seems to be a fleeting event. I do find with Peet’s Major Dickason’s whole coffee beans, my results are more reliable and consistent.While I drink several other beans and constantly try others, Peet's Major Dickason's Whole Beans are my go to coffee several days a week.I am a dedicated espresso drinker, but it has taken me years to make a good espresso at home. Saying "good" however, is a matter of opinion. I have had good espressos at some cafes and restaura...
# 5  This is a review for the addon listing of Peet's Major Dickerson blend.I've been a Peet's convert for a while now, in fact Peet's ruined my preference for medium roasts with it's Maj D blend and I was quite a coffee snob willing to spend more for quality at other website roasters typically ordering around 7 lbs a month.  But when I discovered Maj D I was surprised at how rich, complex and satisfying of a roast it was.  For a while I ordered from their website but I'd check in with amazon fro...
#
#    Positive
# 0         1
# 1         1
# 2         1
# 3         1
# 5         1

# %%
#ALGUNOS REVIEWS NEGATIVOS
df_reviews[df_reviews.Positive == 0].head()
# Out:
#     Index  \
# 4       4
# 9       9
# 14     14
# 20     20
# 24     24
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Comment  \
# 4                                                                                                                                                                                     Disappointed. Received the package 12/20 that was roasted 9/18 and best by 12/17 so past the best by date. Usually when ordering via Amazon things are much fresher. I won't be ordering this product again. Which is a shame because it is quite good. Usually you get a discount for out of date products not a full price tag.
# 9   UPDATED April 2018: Peet's stop making the decaf house blend over 6 months ago. On February I saw it back here and  I purchased 4 of them thinking that after it was discontinue they brought it back, big mistake, this is nothing like the old decaf house blend, it is bitter and the flavor is very bad. I wasted my money buying these. Not sure why they even call it the same if it is different coffee taste. I trashed all of them.By far one of the best decaf coffees out there. It is better if you ...
# 14                                         Made my usual cold brew with my Toddy, and was recommended to try this by a friend. Typically I'll spend a few extra dollars for some of my favorite dark roast coffee beans, but wanted to see if I could save some money while still having a great cold brew. Unfortunately, I found this to be unusually bitter and strong with my regular 12 hour process. Perhaps this is best left as a hot brewed coffee, as there's just no body or discernible flavor notes to it.
# 20                                                                                                                                                                                                                                                                                                                                                     Delivered 10/5/17.  Product 'best purchased by' 10/11/17.  Not the first time this has happened; be careful when purchasing.  Always check dates before opening.
# 24                                                                                                                                                                                                                                                                                                                                                                                                Coffee beans are obviously old. No aroma, absolutely no flavor. I'm stuck with 3 more bags which are of no use to me.
#
#     Positive
# 4          0
# 9          0
# 14         0
# 20         0
# 24         0

# %%
df_reviews.to_csv('reviews.csv', sep='|', encoding='utf-8')

# %% [markdown]
# #### PASO5: ENTRENAMIENTO DEL MODELO CON LOS DATOS EXTRAIDOS Y LAS CALIFICACIONES

# %%
X = data[:,:-1]
Y = data[:,-1]

# %%
''' SE DIVIDEN LOS REVIEWS EN UN SET DE APRENDIZAJE Y UNO DE PRUEBA '''
#80% DE APRENDIZAJE Y 20% DE PRUEBA

Xtrain = X[:-int(N*0.2),]
Ytrain = Y[:-int(N*0.2),]

Xtest = X[-int(N*0.2):,]
Ytest = Y[-int(N*0.2):,]

# %%
''' SE UTILIZA REGRESSION LOGISTICA PARA DEFINIR LOS PESOS ADECUADOS
    QUE PREDIGAN SI UN REVIEW ES NEGATIVOS O POSITIVOS CON BASE EN LA
    COMBINACION DE PALABRAS QUE CONTENGA    '''

model = LogisticRegression()
model.fit(Xtrain, Ytrain) #Calcula los pesos
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print("Precisión con el set de entrenamiento:", model.score(Xtrain, Ytrain))
print("Precisión con el set de prueba:", model.score(Xtest, Ytest))
# Out:
# Precisión con el set de entrenamiento: 0.8341323106423778
# Precisión con el set de prueba: 0.7538461538461538

# %% [markdown]
# #### PASO6: CON LOS EL MODELO SE PERMITE PREDECIR CUALES FUTUROS REVIEWS SERAN NEGATIVOS O POSITIVOS
# También se pueden observar varias palabras que definen cuando un comentario es positivo o negativo

# %%
''' EL MODELO RETORNARA UN COERFICIENTE NEGATIVO O POSITIVO PARA CADA PALABRA '''
''' EJEMPLO DE PALABRAS MAS POSITIVAS'''

threshold = 0.5
print('RATE','\t','WORD')
for word, index in iteritems(word_index_map):
    weight = model.coef_[0][index]
    if weight > threshold:
        print(round(weight,1),'\t',word)
# Out:
# RATE 	 WORD
# 0.6 	 morning
# 2.5 	 coffee
# 1.2 	 rich
# 0.9 	 price
# 0.7 	 peet
# 1.0 	 flavor
# 0.5 	 amazing
# 2.0 	 favorite
# 0.5 	 french
# 0.7 	 roast
# 0.8 	 perfect
# 1.8 	 love
# 0.7 	 smooth
# 0.6 	 store
# 0.8 	 nice
# 1.2 	 decaf
# 0.9 	 tasting
# 1.4 	 excellent
# 0.6 	 brand
# 0.8 	 bold
# 0.9 	 peets
# 1.4 	 delicious
# 0.6 	 tasty
# 0.5 	 expected
# 0.7 	 yummy

# %%
''' EJEMPLO DE PALABRAS MAS NEGATIVAS'''

threshold = -0.5
print('RATE','\t','WORD')
for word, index in iteritems(word_index_map):
    weight = model.coef_[0][index]
    if weight < threshold:
        print(round(weight,1),'\t',word)
# Out:
# RATE 	 WORD
# -0.6 	 roasted
# -0.8 	 bean
# -1.3 	 bitter
# -0.8 	 stale
# -3.0 	 date
# -0.6 	 disappointed
# -0.6 	 month
# -1.6 	 received
# -0.6 	 bag
# -0.7 	 burnt
# -0.5 	 expiration
# -1.1 	 expired
# -0.7 	 sorry
